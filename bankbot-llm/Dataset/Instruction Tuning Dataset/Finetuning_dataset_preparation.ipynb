# %% [markdown]
# # Preparing Datasets for Finetuning

# %% [markdown]
# ## Loading *NUST Bank Products Knowledge* dataset

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /home/muhammadbinusman/miniconda3/lib/python3.12/site-packages (2.2.3)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/muhammadbinusman/miniconda3/lib/python3.12/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/muhammadbinusman/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/muhammadbinusman/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/muhammadbinusman/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in /home/muhammadbinusman/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd

# Load the Excel file
excel_file = pd.ExcelFile('/home/muhammadbinusman/Downloads/NUST Bank-Product-Knowledge.xlsx')

# Print available sheet names
excel_file.sheet_names
# Out:
# ['Main',
#  'Rate Sheet July 1 2024',
#  'LCA',
#  'NAA',
#  'NWA',
#  'PWRA',
#  'RDA',
#  'VPCA',
#  'VP-BA',
#  'VPBA',
#  'NSDA',
#  'PLS',
#  'CDA',
#  'NMA',
#  'NADA',
#  'NADRA',
#  'NUST4Car',
#  'ESFCA',
#  'NFDA',
#  'NSA',
#  'PF',
#  'NMC',
#  'NMF',
#  'NSF',
#  'NIF',
#  'NUF',
#  'NFMF',
#  'NFBF',
#  'PMYB &ALS',
#  'NRF',
#  'NHF',
#  'Nust Life',
#  'EFU Life',
#  'Jubilee Life ',
#  'HOME REMITTANCE',
#  'Sheet1']

# %% [markdown]
# ## Extracting QA Pairs from all sheets

# %%
def extract_qa_pairs(df, column_name):
    qa_pairs = []
    rows = df[column_name].tolist()
    
    question_keywords = ("what", "when", "why", "how", "who", "where", "which", "can", "does", "is", "are", "do", "did")  # you can extend this list
    
    i = 0
    while i < len(rows):
        cell = rows[i]
        
        if isinstance(cell, str):
            cell_stripped = cell.strip().lower()
            
            # Check if it starts with a question word OR ends with '?'
            if cell_stripped.startswith(question_keywords) or cell.strip().endswith("?"):
                question = rows[i]
                
                # Get answer from next row (if exists)
                if i + 1 < len(rows):
                    answer = rows[i + 1]
                    if not isinstance(answer, str):
                        answer = ""
                    qa_pairs.append((question.strip(), answer.strip()))
                else:
                    qa_pairs.append((question.strip(), ""))
                
                i += 2  # move past the answer
            else:
                i += 1
        else:
            i += 1
    
    return qa_pairs

# %% [markdown]
# Loop through all sheets and create qa-pairs list

# %%
qa_dict = {}

for sheet_name in excel_file.sheet_names:
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    
    # Identify the first non-unnamed column
    named_columns = [col for col in df.columns if not str(col).startswith('Unnamed')]
    
    if named_columns:
        target_column = named_columns[0]
        qa_list = extract_qa_pairs(df, target_column)
        qa_dict[sheet_name] = qa_list
        print(f"Extracted {len(qa_list)} Q-A pairs from sheet '{sheet_name}' using column '{target_column}'")
    else:
        print(f"No named column found in sheet '{sheet_name}', skipping.")
# Out:
# Extracted 0 Q-A pairs from sheet 'Main' using column 'NUST BANK PRODUCTS (CONVENTIONAL)
# (Click on any product below)'
# Extracted 0 Q-A pairs from sheet 'Rate Sheet July 1 2024' using column 'Main'
# Extracted 6 Q-A pairs from sheet 'LCA' using column 'Little Champs Account '
# Extracted 5 Q-A pairs from sheet 'NAA' using column 'NUST Asaan Account (NAA) '
# Extracted 5 Q-A pairs from sheet 'NWA' using column 'NUST Waqaar Accounts'
# Extracted 7 Q-A pairs from sheet 'PWRA' using column 'PakWatan Remittance Account '
# Extracted 7 Q-A pairs from sheet 'RDA' using column 'Roshan Digital Account '
# Extracted 4 Q-A pairs from sheet 'VPCA' using column 'Value Plus Current Account'
# Extracted 6 Q-A pairs from sheet 'VP-BA' using column 'Value Plus Business Account'
# Extracted 6 Q-A pairs from sheet 'VPBA' using column 'NUST Value Premium Business Account'
# Extracted 5 Q-A pairs from sheet 'NSDA' using column 'NUST Special Deposit Account '
# Extracted 4 Q-A pairs from sheet 'PLS' using column 'Profit and Loss Sharing Account (PLS)'
# Extracted 4 Q-A pairs from sheet 'CDA' using column 'Current Deposit Account'
# Extracted 5 Q-A pairs from sheet 'NMA' using column 'NUST Maximiser Accounts (Savings/Deposit)'
# Extracted 6 Q-A pairs from sheet 'NADA' using column 'NUST Asaan Digital Account '
# Extracted 5 Q-A pairs from sheet 'NADRA' using column 'NUST Asaan Digital Remittance Account '
# Extracted 19 Q-A pairs from sheet 'NUST4Car' using column 'NUST4Car : Auto Finance Facility'
# Extracted 5 Q-A pairs from sheet 'ESFCA' using column 'Exporters’ Special Foreign Currency Account – ESFCA'
# Extracted 5 Q-A pairs from sheet 'NFDA' using column 'NUST Freelancer Digital  Account '
# Extracted 14 Q-A pairs from sheet 'NSA' using column 'NUST Sahar Accounts'
# Extracted 13 Q-A pairs from sheet 'PF' using column 'NUST Personal Finance'
# Extracted 13 Q-A pairs from sheet 'NMC' using column 'NUST Bank Mastercard '
# Extracted 20 Q-A pairs from sheet 'NMF' using column 'NUST Bank Mortgage Finance '
# Extracted 15 Q-A pairs from sheet 'NSF' using column 'NUST Sahar Finance'
# Extracted 18 Q-A pairs from sheet 'NIF' using column 'NUST Imarat Finance'
# Extracted 14 Q-A pairs from sheet 'NUF' using column 'NUST Ujala Finance'
# Extracted 10 Q-A pairs from sheet 'NFMF' using column 'NUST Flour Mill Finance'
# Extracted 15 Q-A pairs from sheet 'NFBF' using column 'NUST Fauri Business Finance'
# Extracted 14 Q-A pairs from sheet 'PMYB &ALS' using column 'Prime Minister Youth Business & Agriculture Loan Scheme'
# Extracted 10 Q-A pairs from sheet 'NRF' using column 'NUST Rice Finance'
# Extracted 12 Q-A pairs from sheet 'NHF' using column 'NUST Hunarmand Finance '
# Extracted 4 Q-A pairs from sheet 'Nust Life' using column 'NUST Life Bancassurance Policy'
# Extracted 4 Q-A pairs from sheet 'EFU Life' using column 'EFU Life Bancassurance Policy'
# Extracted 4 Q-A pairs from sheet 'Jubilee Life ' using column 'Jubilee Life Bancassurance Policy'
# Extracted 20 Q-A pairs from sheet 'HOME REMITTANCE' using column 'Home Remittances'
# No named column found in sheet 'Sheet1', skipping.

# %%
qa_dict
# Out:
# {'Main': [],
#  'Rate Sheet July 1 2024': [],
#  'LCA': [('I would like to open an account with my son, do u have any product for kids?',
#    'Yes our product is Little Champs Account. It is designed specifically for minors (individuals below the age of 18 years). A child requires the help of a parental/legal guardian to open this account and avail its facilities. Little Champs get a Debit Card and chequebook which is free the first time'),
#   ('What are the main Features  of the Little Champs Account.',
#    'Minimum initial deposit of Rs.100/-'),
#   ('What other Value added features does the Little Champs Account have?',
#    'Attractive returns on savings account'),
#   ('What is the account type of Little Champs Account is it saving or current ?',
#    'This account is offered both in current and savings categories'),
#   ('How can the minor operate this account?',
#    'This account is opened in the name of the minor. However, a minor needs a guardian’s help to avail the account’s facilities'),
#   ('What documents are required to open a Little Champs Account.',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 A photocopy of Form-B, Birth Certificate or Student ID card (as appropriate) of the minor')],
#  'NAA': [('What is the Eligibility Criteria for NAA?',
#    'Resident Pakistani individuals who do not maintain/have any other account (single or joint) in NUST Bank Limited are eligible to open the NAA in Pak rupees as a single/joint account.'),
#   ('What is the account type of NAA?',
#    'NAA can be opened both in Current & Savings'),
#   ('What is the opening and minimum balance requirement in NAA?',
#    'Account can be opened with Rs.100/ and there is\xa0No minimum balance requirement.'),
#   ('What are the basic Features  of NUST Asaan Account?',
#    'o\xa0Bi-annual account statements'),
#   ('What is the Profit rate on NAA Savings account?',
#    'Current profit rate is 20.50% which is paid Semi Annually.')],
#  'NWA': [('Does your bank offer any account for senior citizens?',
#    'NUST Waqaar Account has been developed for senior citizens, enabling them to carry out their banking transactions and also to avail investment opportunities.'),
#   ('What are the salient features of NUST Waqaar Account ?', 'Tenure'),
#   ('What identity documents are required to open NUST Waqaar Account?',
#    'A photocopy of any one of the following valid identity documents:'),
#   ('What is the minimum age to qualify for opening of  NUST Waqaar Account & Minimum deposit requirement ?',
#    'Minimum age to qualify is 55 years'),
#   ('What is the minimum deposit requirement to open NUST Waqaar Savings Account & NUST Waqaar Term Deposit?',
#    '- Minimum deposit for opening of the NUST Waqaar – Savings account is Rs.1,000')],
#  'PWRA': [('Is there any account NUST Bank is offering for remittance purposes ?',
#    'Yes PakWatan Remittance Account. \nThrough the PakWatan Remittance Account, beneficiaries can quickly and securely receive remittances from their loved one living abroad directly into their bank account without visiting the branch.'),
#   ('What are initial/minimum balance requirements for PakWatan Remittance Account?',
#    'No initial deposit requirement'),
#   ('Are Local Credits allowed in PakWatan Remittance Account?',
#    'Local credits are also allowed in PakWatan Remittance Account'),
#   ('What are the free services associated with PakWatan Remittance account?',
#    'Free services include:'),
#   ('Are there any other benefits to opening a PakWatan Remittance Account?',
#    'o  WHT exemption on cash withdrawal on home remittances received from abroad'),
#   ('Is there any Insurance Coverage for this account?',
#    'o\xa0\xa0 ATM Cash Withdrawal Insurance coverage up to daily cash withdrawal limit of the debit card from NUST Bank ATMs'),
#   ('What is the profit rate offered on this account and when is credited?',
#    'Profit payment on monthly basis based on monthly average balance')],
#  'RDA': [('Does NUST Bank offer Any account for Non-Resident Pakistanis (NRPs)?',
#    'Yes Roshan Digital Account. Specially Designed for Individual Non-Resident Pakistanis (NRPs) seeking to undertake banking, payment and investment activities in Pakistan.'),
#   ('Is there any minimum balance requirement of Roshan Digital Account?',
#    'No initial deposit requirement'),
#   ('What are the main features of the Roshan Digital Account?',
#    'Offered in PKR and USD/GBP/EUR'),
#   ('What are the free facilities ?',
#    'Free First Issuance of Debit Card- Annual charges as per prevailing SOC'),
#   ('How to apply for Roshan Digital Account ?',
#    'Customer can visit NUST Bank’s website and click on "Apply for Roshan Digital Account" to open NUST Roshan Digital Account. ◦'),
#   ('What is the NUST Bank Web Portal Link for RDA?',
#    'https://secureportal.NUSTbank.com/rda/'),
#   ('Who can open a Roshan Digital Account?', 'NRPs')],
#  'VPCA': [('I would like to inquire about opening a current account for Individuals with your Bank. Please tell me what options I have ?',
#    'NUST Value Plus Current Account is specially designed for individuals to cater their financial needs.'),
#   ('What are the free facilities being provided with NUST Value Plus Current Account?',
#    '- Cheque Books (unlimited)'),
#   ("Are there any insurance benefits associated with VPCA'?",
#    '- ATM Cash Withdrawal Insurance Coverage'),
#   ('What is the opening and minimum balance requirement for VPCA?',
#    '- No Opening Balance Requirements')],
#  'VP-BA': [('I would like to inquire about opening a current account for business with your Bank. Please tell me what options I have?',
#    'NUST Value Plus Business Account is best suited for startups and businesses'),
#   ('Please tell me about  Free Facilities being provided on Value Plus Current Account for Business upon maintaining minimum Monthly average Balance ?',
#    'Issuance of Cheque Books'),
#   ('Issuance of Debit Card*', 'Internet\xa0Banking facility'),
#   ('Please tell me about  minimum Monthly balance required ?',
#    'No initial deposit requirement'),
#   ('What is Target Market for  Value Plus Business Account ?',
#    'Sole Proprietors\nGeneral Partnership\nSmall Enterprises'),
#   ('Is there any insurance coverage available?',
#    'ATM Cash Withdrawal Insurance \nSpeedy processing of SBP Kamyab Jawan loans')],
#  'VPBA': [('I would like to inquire about opening a current account for business purpose with your Bank. Please tell me what options I have?',
#    'NUST Value Premium Business Account has been designed to better meet the specialized banking needs of businesses that continue to grow with time.'),
#   ('Please tell me about  Free Facilities being provided on Value Plus Current Account for Premium Business  upon maintaining minimum Monthly average Balance?',
#    'Issuance of Cheque Books*'),
#   ('Issuance of Debit Card*', 'Internet\xa0Banking facility'),
#   ('Please tell me about  the Minimum Monthly balance required for this account?',
#    'No initial deposit requirement'),
#   ('What other benefits do I get from using a VPBA?',
#    'Speedy processing of Financing'),
#   ('What is the Target Market for Value Plus Premium Business Account ?',
#    'Medium Enterprises')],
#  'NSDA': [('Is\xa0NUST Bank\xa0offering any account which provides lucrative profits on my savings?',
#    'NUST Special Deposit Account (ASDA) is specially designed for large ticket customers to meet  their transactional and savings needs.'),
#   ('What is the minimum balance requirement of NUST Special Deposit Account?',
#    'No Minimum Monthly Average Balance Requirement'),
#   ('Please tell me about profit payment and calculation?',
#    'Profit Payment Frequency- Monthly'),
#   ('What are the free services available with ASDA?',
#    'Free E-statement & I-Net Banking'),
#   ('What is the Target Market?',
#    'HNW Individuals (either singly or jointly)')],
#  'PLS': [('Is your bank offering Profit & Loss account ?',
#    'Yes, Profit & Loss Sharing Account is specially designed to meet the transactional and savings need of customers.'),
#   ('What are the main features of NUST Profit & Loss Sharing (PLS) Account?',
#    'Offered in LCY (PKR) & FCY (USD, GBP, EUR, JPY & AED)'),
#   ('What are free features available with NUST Savings Profit & Loss Sharing (PLS) Account.',
#    'Free E-statement & I-Net Banking'),
#   ('What is the Target Market?', 'Individuals (either singly or jointly)')],
#  'CDA': [('Is your bank offering\xa0any Current Deposit account ?',
#    'Current Deposit Account is specially designed for customers with regular banking transactional needs and do not need Profit.'),
#   ('What are the main features of Current Deposit Account?',
#    'Offered in LCY (PKR) & FCY (USD, GBP, EUR, JPY & AED)'),
#   ('What are the free services offered with Current Deposit Account?',
#    'Free SMS alerts facility on Digital Transactions'),
#   ('What is the target market for Current Deposit Account?',
#    'Individuals (either singly or jointly)\nProprietorship Concerns, Business Owners \nPartnership Firms \nPublic and Private Limited Companies\nGovernment Organizations\nCorporations, Clubs, Societies, NGOs etc.')],
#  'NMA': [('Is\xa0there any account which provides lucrative profits on my long term savings?',
#    'Yes, NUST Maximiser Account has been designed to fulfill your basic banking needs and provide lucrative profit on your savings.'),
#   ('What are the main Features of NUST Maximiser Savings Account?',
#    '-\xa0 Attractive profit payment on monthly, quarterly, semi-annual & annual basis:'),
#   ('What are the free services available with NUST Maximiser Savings Account?',
#    'o\xa0\xa0 Bankers Cheque Issuance'),
#   ('What are main Features of NUST Maximiser Term Deposit',
#    '- Tenure: 1, 2, 3 & 5 Years'),
#   ('Is there any Premature Encashment Penalty in NUST Maximiser Term Deposit?',
#    'The encashment of NUST Maximiser Term Deposit before maturity will be subject to premature encashment penalty as below:')],
#  'NADA': [('Is NUST Bank offering a simple Digital Banking Account  ?',
#    'Yes, NUST Asaan Digital Account is being offered'),
#   ('What is the Target  Market of NUST Asaan Digital Account ?',
#    'NUST Asaan Digital Account is specially designed for unbanked / under-banked customer segments. This account is most suited for but not limited to skilled/unskilled workforce'),
#   ('What is the Account type of NUST Asaan Digital Account ? is it Current or Saving?',
#    'NUST Asaan Digital account is a Current Account in PKR currency'),
#   ('What are the free benefits of NUST Asaan Digital Account ?',
#    'Free Issuance of First Cheque book (25 Leaves)*'),
#   ('Who is eligible for this account?', 'Skilled/Unskilled Workforce'),
#   ('Is there a Monthly Transaction Limit (Debit  and Credit Limit) in NUST Asaan Digital Account ?',
#    'Maximum Credit Balance Limit  PKR 1,000,000/-')],
#  'NADRA': [('I would like to inquire about opening of a Digital Remittance Account, Please tell me what options are available?',
#    'NUST Asaan Digital Remittance Account is specially designed for Pakistani Resident Individuals who wish to receive remittances from their families and friends living abroad, directly in a bank account without the hassle of visiting the branch.'),
#   ('What is the Account type of NUST Asaan Digital Remittance Account ? is it Current or Saving?',
#    'NUST Asaan Digital Remittance account is a Current Account in PKR currency'),
#   ('What are the free benefits of NUST Asaan Digital Remittance Account ?',
#    'Free Issuance of First Cheque book (25 Leaves)*'),
#   ('What is the Target Market?',
#    'Individuals- Beneficiaries (families) of Pakistanis working abroad'),
#   ('Are there any transaction limits in NUST Asaan Digital Remittance Account ?',
#    'The following Transaction limits apply:')],
#  'NUST4Car': [('1.What are the benefits of NUST Bank Auto Finance?', ''),
#   ('2. Who can apply for NUST Auto Finance?',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Salaried Individuals'),
#   ('3. Which types of Vehicles are offered under NUST auto finance?',
#    'Locally assembled/manufactured'),
#   ('4. Can I avail Loan Facility, if there are defaults against my previous loan(s)?',
#    'No. Regular payment against previous loans is necessary.'),
#   ('5. How much loan can I avail?',
#    'Up to a maximum of Rs.3 Million from all banks/DFIs in aggregate, subject to a maximum of 40% Debt Burden requirement.'),
#   ('6. What is maximum period of loan?',
#    'Up to 1000 CC Vehicles                                       up to 5 Years'),
#   ('7. How much Equity/Down Payment is required?',
#    'Minimum 30%  equity +(1st Year Insurance + documentation charges) is required as down payment'),
#   ('8. Can I avail more than one vehicle through Auto loan facility?',
#    'Yes. Two vehicles can be availed simultaneously from NUST Bank, subject to Debt Burden Limitations'),
#   ('Professional?',
#    'Yes. The individual  with  foreign remittance, supported by Bank statement  and remittance receipts can avail Auto Loan Facility'),
#   ('10. Are there any hidden charges?',
#    'There are no hidden charges. All charges are mentioned in our Schedule of Charges available at our website and at all branches of NUST Bank.'),
#   ('11. Is insurance of vehicle is mandatory?',
#    'Yes. Comprehensive Insurance of vehicle is mandatory for the whole tenor of loan at the cost of the borrower'),
#   ('12. What will be the monthly insurance charges on the vehicle valuing Rs.3 million?',
#    'With the current insurance rate of 1.75% per annum, it will be Rs.4,375/- per month.'),
#   ('13. Who will insure my Vehicle?',
#    'NUST Bank has insurance arrangements with reputed insurance companies with attractive insurance rate,'),
#   ('14. Can I pay my loan before maturity?',
#    'Yes. You can pay your loan before maturity. However, charges shall be applicable as per prevailing SOC'),
#   ('15. What is the security against the loan?',
#    'Financed vehicle will be the security against the loan, which will be hypothecated in favour of NUST Bank.'),
#   ('16. Whether bank is responsible for delay in booking or delivery of vehicle?',
#    'No. Bank does not assume any responsibility in this regard, as same is beyond the control of bank.'),
#   ('17. Whether bank is responsible for any type of dispute related to Warranty/Fault in vehicle/Service issues with Dealership or vehicle Manufacturer?',
#    'No. Bank does not assume this responsibility. Customer will take up the matter directly with dealership or manufacturer.'),
#   ('18. What is the Loan Application processing time?',
#    'The processing time for loan approval is approximately 11 working days, subject to complete application with required documents/formalities.'),
#   ('19. How can I apply for loan?',
#    'You can apply by visiting any of our  Branch or by calling us at 24 hours Contact Centre at 111-000-787.')],
#  'ESFCA': [('Does NUST Bank offer a Digital Banking Account for Freelancers ?',
#    'NUST Freelancer Digital Account is exclusively designed for Freelancers, so that they can receive their payments directly in a bank account and enjoy other lifestyle banking services as well.'),
#   ('What is the Account type of NUST Freelancer Digital Account ? is it Current or Saving?',
#    'NUST Freelancer Digital Account offered Current Account in PKR & FCY (USD, GBP, EUR, AED)'),
#   ('What are the free benefits of NUST Freelancer Digital Account?',
#    'Free Issuance of First Cheque book (25 Leaves)*'),
#   ('What is the Target Market?',
#    'Individuals running a freelance service business'),
#   ('Are there any Credit and Debit limits in NUST Freelancer Digital Account?',
#    'The following Transaction limits apply:')],
#  'NFDA': [('Does NUST Bank offer a Digital Banking Account for Freelancers ?',
#    'NUST Freelancer Digital Account is exclusively designed for Freelancers, so that they can receive their payments directly in a bank account and enjoy other lifestyle banking services as well.'),
#   ('What is the Account type of NUST Freelancer Digital Account ? is it Current or Saving?',
#    'NUST Freelancer Digital Account offered Current Account in PKR & FCY (USD, GBP, EUR, AED)'),
#   ('What are the free benefits of NUST Freelancer Digital Account?',
#    'Free Issuance of First Cheque book (10 Leaves)*'),
#   ('What is the Target Market?',
#    'Individuals running a freelance service business'),
#   ('Are there any Credit and Debit limits in NUST Freelancer Digital Account?',
#    'The following Transaction limits apply:')],
#  'NSA': [('Is NUST Bank offering any account specifically for Women?',
#    '- Yes! NUST Bank Offers NUST Sahar Account.'),
#   ('What is the account type of NUST Sahar Account?',
#    'NUST Sahar Deposit suite consists of following variants:'),
#   ('What are the free facilities NUST is offering on NUST Sahar Current Account ?',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 First Cheque Book'),
#   ('Can we open this account online?',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Digital account opening facility available with account opening within 48 hours'),
#   ('Does the bank offer option of Term Deposits with this account.',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Yes, Option to book exclusive NUST Sahar Term Deposits from NUST Sahar Current Account at attractive rates is available.'),
#   ('Is there a Minimum balance requirement for NUST Sahar Current Account',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 No minimum average balance requirement for account maintenance'),
#   ('What is the profit payment system for NUST Sahar Savings Account ?',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Monthly Profit Payment'),
#   ('What are the free services offered on NUST Sahar Savings Account?',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 First Debit Card Issuance*'),
#   ('What are the main features of NUST Sahar Term Deposit ?',
#    '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Flexibility to choose from multiple tenure: 1, 3 or 5 Years'),
#   ('What is the Premature Encashment Penalty on NUST Sahar Term Deposit ?',
#    '- The encashment of NUST Sahar Term Deposit before maturity will be subject to premature encashment penalty as below:'),
#   ('What is the initial deposit requirement of NUST Sahar Asaan Current Account?',
#    '- Rs. 100 only'),
#   ('What are the main features of NUST Sahar Asaan Current Account ?',
#    '- Simplified Account Opening with single pager Account Opening form & CNIC'),
#   ('Is there any Transaction Limitation for NUST Sahar Asaan Current Account ?',
#    '- Monthly withdrawal limits up to Rs. 1,000,000'),
#   ('What are the free services offered on NUST Sahar Asaan Current Account ?',
#    '- Free Inter Branch Online Cash Deposit/Withdrawal (Online)')],
#  'PF': [('Who can apply for NUST Personal Finance?',
#    '1· Armed Forces Officers\n\t - Serving employees\n\t - Retired employees\n\n2.\tJCOs/Equivalent & Lower Cadres\n\t - Serving employees\n\t - Retired employees\n\n3.\tAllied Armed Forces (SPD & its allied concerns) and Civilians (in GHQ/NHQ & AHQ)\n\t - Serving employees (Permanent & Contractual Employees)\n\n4.\tFauji Foundation Group\n\t - Permanent employees\n\t - Contractual employees'),
#   ('Can overseas Pakistanis obtain Personal Finance facility from NUST?',
#    'No, the availability of applicants & their employers is mandatory within Pakistan for applying clean Personal Finance.'),
#   ('What is the minimum and maximum financing amount?',
#    'The minimum financing amount is Rs. 50,000/ (Rs. 35,000 for retired JCOs & Lower Cadre - Subject to pension with NUST).'),
#   ('What are the minimum & maximum financing tenures?', 'Minimum 01 year'),
#   ('What is the age criteria for applying NUST Personal Finance?',
#    'Minimum:\nSalaried:  21 years (18 years for Armed Forces)\nSEB/SEP:  23 years\nPrime Customers:  25 years'),
#   ('What is the minimum monthly income criterion?',
#    'Salaried (Approved Company):\n - Category A Company - PKR 40,000 (Permanent) & PKR 60,000 (Company / 3rd Party Contractual)\n - Category B & C Company - PKR 50,000 (Permanent) & PKR 60,000 (Company / 3rd Party Contractual)\n\nSalaried (Non-approved Company):\n - PKR 70,000 (Permanent) & PKR 80,000 (Company Contractual)\n\nSalaried (GOP):\n - Serving - PKR 35,000 (Permanent, BPS-5 & above) & PKR 45,000 (Contractual)\n - Retired - PKR 40,000 subject to pension with NUST'),
#   ('In which area of the country one can avail Personal Finance form NUST?',
#    'Personal Finance can be availed from all cities where NUST branches exists.'),
#   ('What is the Application processing time?',
#    'The processing time of Personal Finance is 10 working days form login till approval (subject to complete application with required documents).'),
#   ('What is the Application processing Charges?',
#    'It will be as per prevailing Schedule of Charges (SOC) or As per corporate arrangement.'),
#   ('What is the repayment mode?',
#    'Payment of Equal Monthly Instalment (EMI) comprising of principal, mark-up and insurance payment will be made through Direct Debit Authority (DDA) of borrower’s account maintained with NUST.'),
#   ('Can I make balloon payments or premature termination of facility?',
#    'Yes, Balloon payment or premature termination option is available for all customers.\nCharges will be applied as per prevailing Bank’s schedule of charges / As per corporate arrangement.'),
#   ('What happens if I fail to fulfil your payment obligations?',
#    'In case of overdue / default, recovery department of NUST will contact you, your loan related details will be reported to Credit Bureau.'),
#   ('How will I get update of my Personal Loan Application?',
#    'You can\xa0visit/ call or send email at our Customer Services centre(s) as well.')],
#  'NMC': [('1.Who can apply for NUST Credit Card Facility?',
#    'Salaried Individuals'),
#   ('2.What is the minimum age for applying NUST Mastercard Credit Card?',
#    'Minimum 21 years old & Pakistani resident, can apply for NUST MasterCard Credit Card.'),
#   ('3. What is the maximum age for applying NUST Mastercard Credit Card?',
#    'Salaried (Permanent):  60 years'),
#   ('4.Can overseas Pakistanis obtain Credit Card facility from NUST?',
#    'Yes. The individuals maintaining FC account with NUST, Remittances/ Roshan Digital Account holders/'),
#   ('5. What is the minimum and maximum financing amount?',
#    'Clean facility, Minimum Rs. 30,000/- and maximum up to 3.0 Million or as per 40% Debt Burden Ratio subject to SBP PRs.'),
#   ('6. What would be the financing tenure?',
#    'NUST Credit Card is an Evergreen facility & renewable after expiry of credit card.'),
#   ('7. What is the minimum monthly income criterion?',
#    'GOP / Semi Govt. / Autonomous Bodies etc: Permanent, Rs. 35,000/- Contractual, Rs. 45,000/-'),
#   ('8. In which area of the country one can avail Credit Card facility?',
#    'Credit Card can be availed from all cities / Areas without discrimination'),
#   ('9. What is the Application processing time?',
#    'The processing time of Credit Card facility is 10 working days form login till approval subject to complete application with required documentation'),
#   ('10. What are the Application Processing Charges?',
#    'Processing Charges will be as per prevailing Bank’s Schedule of Charges (SOC).'),
#   ('11. What happens if I fail to fulfil your payment obligations?',
#    'In case of overdue / default, recovery department of NUST will contact you, your loan related details will be reported to Credit Bureau. Late payment and cheque return charges may also be applicable as per prevailing schedule of charges. Legal proceeding may also be initiated by the Bank.'),
#   ('12. How will I get update of my Credit Card Application?',
#    'You can visit/ call or send email at our Customer Services centre(s) as well. Services centre(s) as well.'),
#   ('13. Is there a limit to international Spending?',
#    'As per SBP directives i.e. Nov 1, 2022 industry-wide annual maximum limit of USD 30,000/- per individual on card-based')],
#  'NMF': [('1.What types of Housing Finance products does NUST offer?',
#    'Purchase of House/ Apartment/ Flat/ Residential Unit'),
#   ('2.What is the minimum age for applying NUST Mortgage Finance?',
#    'Salaried : 21 Years'),
#   ('3. What is the Maximum age criteria for applying NUST Mortgage Finance?',
#    'Salaried Permanent : 60 Years at the maturity of loan\nSalaried Contractual: 65 Years at the Matrurity of loan\nPensioners: 65 Years at the maturity of loan\nSEB/SEP: 65 Years at the maturity of loan'),
#   ('4.Can overseas Pakistanis obtain House Finance facility from NUST?',
#    'Yes. However can apply as Co-Borrower with veriable income. Basic borrower from Pakistan should also meet the required basic criteria for MF.'),
#   ('5. What is the minimum and maximum financing amount?',
#    'The minimum financing amount is Rs. 500,000/. \nThe maximum financing limit will be up to Rs.100,000,000/- subject to 50% Debt Burden Ratio(DBR) as per SBP PRs for Housing Finance.'),
#   ('6. What would be the financing tenure?',
#    'Loan tenure is Minimum 3 years and maximum 25 years'),
#   ('7. Can I obtain financing on my owned property by mortgaging it?',
#    'Yes, purpose of finance has to be in line with the purpose defined by regulator i.e.'),
#   ('8. Can I avail more than one House loan?',
#    'Yes. One can avail two Mortgage Loans at a time from NUST Bank within Debt Burden Ratio (DBR) as per prevailing SBP PRs for Housing Finance.'),
#   ('9. Can I avail income tax rebate on House Financing?',
#    'Yes, one can claim tax rebate against its House Finance mark-up paid during the year, or as per prevailing Tax laws of the country.'),
#   ('10. What is the minimum monthly income criterion?',
#    'Salaried:\xa0Permanent Rs. 50,000/-, Contractual Rs. 60,000/-, Govt. Employee Contractual 75,000/-'),
#   ('11. Can I club income of Co-Borrower?',
#    'Yes. Clubbing of Co-Borrower income may be allowed in case of spouse/son/parents/un-married daughter/Sibling.'),
#   ('12. What are the processing charges for NUST Mortgage FInance?',
#    'Processing Charges will be as per prevailing Bank’s Schedule of Charges (SOC).'),
#   ('13. What is the repayment mode?',
#    'Payment of Equal Monthly Installment (EMI) comprising of principal, mark-up and Insurance cost etc. will be made through Direct Debit Authority (DDA) of borrower’s account maintained with NUST.'),
#   ('14.\xa0Is Property insurance coverage mandatory?',
#    'Yes. Property Insurance is mandatory; Insurance premium is born by the borrower. It covers construction cost of financed house and value of property in case of apartment.'),
#   ('15. Can I make balloon payments or premature termination is allowed?',
#    'Yes, Balloon payment or premature termination option is available for all customers. Charges will be applied as per prevailing Bank’s schedule of charges.'),
#   ('16. Can the loan amount be used for any other purpose?',
#    'No, the loan amount can only be used for specific purpose i.e.'),
#   ('17.In which area of the country one can avail House Finance form NUST?',
#    'Mortgage Finance facility can be availed from all cities / areas without discrimination.'),
#   ('18. Where financing is not allowed?',
#    'The financing shall not be allowed for;'),
#   ('14. What is the Application processing time?',
#    'The processing time of Mortgage Finance is 30 days form login till approval subject to complete application with required documents.'),
#   ('How will I get update of my House Loan Application?',
#    'Our Sales/ front end staff is quite supportive and always there to serve you. You can visit/call or send email at our Customer Services center(s) as well.')],
#  'NSF': [('Is NUST Bank offering any financing specifically for women owned small and medium enterprises?',
#    'The Product "NUST Sahar Finance" is based on Refinance and Credit Guarantee Scheme for Women Entrepreneurs objective of this product is to provide financing facilities to women owned enterprises to meet credit needs of their businesses.'),
#   ('What are the purposes for which NUST Sahar Finance can be availed?',
#    'i. Expansion of existing business\nii. Set up of new business\niii.Purchase of stocks/ Working Capital Requirement etc'),
#   ('What is the applicant legal structure of business in order to avail NUST Sahar Finance?',
#    'Sole Proprietor, Partnership Firm, Private Limited Company, Single Member Company (SMC), Business Individuals (Women Owned)\n\n*In Partnership firm/ Private Limited Company, having 02 partners or directors, minimum 51% shareholder/ CEO should be a a femle who should also be the applicant. If there are more than 02 partners or directors, major share holder should be women , who should also be CEO and applicant'),
#   ('What is the nature of finance in NUST Sahar Finance?',
#    'i. Long Term Finance\nii. Short Term Finance/Working Capital'),
#   ('What is the maximum tenure of NUST Sahar Finance?',
#    'Short Term Finance/Working Capital\nMaximum 3 years with no grace period'),
#   ('Is there any age criteria to avail NUST Sahar Finance?',
#    'New Business\nBetween 20-50 years at the time of application'),
#   ('What are the Loan Limits of NUST Sahar Finance?',
#    'New Business\nMaximum Loan Rs: 3.00 Million'),
#   ('What is the current Mark-up rate of NUST Sahar Finance?',
#    'Mark-up Rate of @5% p.a.\n*Markup at 12M Kibor + 4% Per Annum to be charged till refinance claim reimbursed by SBP.'),
#   ('Can applicant avail clean loan in NUST Sahar Finance?',
#    'Max Rs: 0.70 million can be availed against personal and third party guarantee'),
#   ('Does the bank require any Equity for this scheme?',
#    'New Business\n20% equity.'),
#   ('Is there any minimum business age requirement?',
#    'Existing Business Should be women owned enterprises with Minimum 01 year of business registration\nNew Business: Nil'),
#   ('What are the processing charges for NUST Sahar Finance Application?',
#    'Up to Rs. 0.70'),
#   ('Are there any late payment charges?',
#    'Rs. 1,000/- per installment\n*In case of delay of installment, commercial rate will be charged on the outstanding principal amount.'),
#   ('What are the service/documentation/legal charges in NUST Sahar Finance?',
#    'At actual'),
#   ('What are the insurance charges?', 'At actual')],
#  'NIF': [('Is NUST Bank offering any financing specifically for the ownership & capacity enhancement of business premises?',
#    'NUST Bank has structured a new financing product “NUST Imarat Finance” under the ambit of SME segment. The Product Program has been developed in order to stabilize SME business through making their ownership of business premises (under mortgage finance of urban commercial / industrial buildings) for capacity enhancement of SMEs.The product has been structured for SMEs owned by general public as well as retired armed forces officers and families of serving officers.'),
#   ('For which purpose NUST Imarat Finance is being offered?',
#    'AIF 1:   Acquisition / Purchase of urban commercial / industrial construted property/ office and commercial premises for commercial / business activity\nAIF 2:   Construction on self owned urban commercial / Industrial plot\nAIF 3:   Additional construction on already built urban commercial/ industrial plaza/building\nAIF 4:   Renovation of self owned urban commercial /industrial property/Plaza/ business premises'),
#   ('What are the Loan Limits of NUST Imarat Finance?',
#    'AIF 1:   Mininum Rs. 5.00 M & Maximum Rs. 100M \nAIF 2:   Mininum Rs. 5.00 M & Maximum Rs. 50M \nAIF 3:   Maximum Rs. 30M or upto 30% of FSV of offered property, whichever is lower\nAIF 4:   Maximum Rs. 5M or upto 25% of FSV of offered property, whichever is lower'),
#   ('What is the maximum tenure of NUST Imarat Finance?',
#    'AIF 1:  Maximum 10 Years (Grace Period upto 6 months)'),
#   ('Does the bank require any Equity for this scheme?',
#    'AIF 1 & AIF 2: Minimum 30%  (Existing business) & Minimum 40% (New Business)\nAIF 3 & AIF 4 : Nil for Existing business & Minimum 25% (New Business)'),
#   ('Is there any minimum age to avail financing in NUST Imarat Finance?',
#    'New Business\nMinimum 30 years at the time of application, however age not to exceed 60 years at maturity of loan.'),
#   ('Any mandatory qualification/experience required?',
#    'Specifically for New Business: \ni)\tOnly Professionals i.e. Chartered Accountants, Doctors, Engineers, IT Professionals, and consultants etc, with minimum 02 years professional experience. \nii)\tRetired professionals from armed forces and families of serving armed forces officers'),
#   ('What is the current Mark-up rate of NUST Imarat Finance?',
#    'General Regular SME’s \nEnd-user Rate: 12MK+4% p.a. (to be reviewed on annual basis)'),
#   ('Is there any business age requirement?',
#    'Existing Business Minimum 03 year operating history of business'),
#   ('What should be the legal structure of business for availing  NUST Imarat Finance?',
#    'Sole Proprietor, Partnership Firm(registered), Private Limited Company, Limited Company'),
#   ('What is the security requirement for availing NUST Imarat Finance?',
#    'i.\tEffective Mortgage (Equitable / or token registered) to be created on same urban Commercial / Industrial property which has been financed\nii.\t03 post dated cheques of the full loan amount plus markup\niii.\tPersonal Guarantees from borrowers, all partners and directors of the companies alongwith “Personal Net worth Statement”.\niv.\tFard based property to be registered equivalent to the full loan amount'),
#   ('What is the repayment frequency in NUST Imarat Finance?',
#    'Monthly/Quarterly'),
#   ('Is there any condition related to bank account maintenance for availing NUST Imarat Finance?',
#    'Minimum 01 year bank account statement with NUST\n                                       Or\nMinimum 02 years bank statement with any other bank'),
#   ('Is there any penalty charges related to Premature termination/balloon payment penalties?',
#    'Mode of Pre-Mature termination'),
#   ('What are the processing charges for NUST Imarat Finance Application?',
#    'Rs 30,000/- or 0.2% of loan amount whichever is higher (Non-refundable)'),
#   ('Are there any late payment charges?', 'Rs. 3,000/- per installment'),
#   ('What are the service/documentation/legal charges in NUST Imarat Finance?',
#    'At actual'),
#   ('What are the valuation/BOQ charges?', 'At actual')],
#  'NUF': [('Is NUST Bank offering any financing product related to renewable/alternate energy solutions?',
#    'NUST Bank has structured a new financing product under the name of “NUST Ujala Finance (NUST Ujala Finance)” in light of SBP’s refinance scheme, under the ambit of SME. The Product Program has been developed to provide financing for installation of solar energy equipment as an alternate source of energy.'),
#   ('who can apply for NUST Ujala Finance?',
#    '1. \tSE/ME Financing \n2. \tVendor’s / Suppliers’ Financing \n3. \tNUST Employees’ Financing   \n4. \tDomestic Applicant Financing (exclusively for employees of corporate / government sector)'),
#   ('Is there any minimum age to avail financing in NUST Ujala Finance?',
#    'SE/ME Financing:  Between 25-55 years at the time of application. (Any one partner/ director should meet age criteria)\nVendors/Suppliers: Between 25-55 years at the time of application. (Any one partner/ director should meet age criteria)\nNUST Employees’ Financing: No age limit   \nDomestic Applicant Financing: Between 25-55 years at the time of application. (Any one borrower or co-borrower should meet criteria)'),
#   ('For which purposes NUST Ujala Finance is being offered?',
#    'SME, NUST Employees and Domestic: Energy generation for own use or for supply to the distribution company / NEPRA'),
#   ('Capacity allowed under NUST Ujala Finance?',
#    'i. Business Enterprise : SE from 10 KW to 200KW, ME from 30 KW to 500KW\nii. Domestic Borrowers from 5 KW to 30KW\niii. NUST employees : upto 30 KW.\nIv. Vendors/Suppliers: from 30 KW to 500KW'),
#   ('Loan Amount that can be availed under NUST Ujala Finance?',
#    'i. Small Enterprise –  upto  Rs. 15 M\nii. Medium Enterprise – upto Rs. 25M\niii. Domestic users    - from Rs. 0.5M to Rs. 3.0M\niv. NUST employees: - upto Rs. 3.00M\nv. Vendors/Suppliers:: From Rs. 5M to 25 Million – (Single Vendor)'),
#   ('What is the current Mark-up rate of NUST Ujala Finance?',
#    '6 % per annum for all\n*Markup at 12M Kibor + 4% Per Annum to be charged till refinance claim reimbursed by SBP.'),
#   ('What is the maximum tenure for NUST Ujala Finance?',
#    'i. SE/ME borrowers:   05 years, inclusive of grace period of 03 months.\nii. Domestic : 05 years inclusive of grace period of 03 months.\niii. NUST employees : 10 years or as per remaining service period (whichever is lesser), inclusive of grace period of 03 months. \niv. Vendors/Suppliers:  05 years inclusive of grace period of 06 months'),
#   ('What is the repayment frequency in NUST Ujala Finance?',
#    'SE/ME Borrowers       :  Monthly  / Quarterly\nDomestic Borrower   :  Monthly \nNUST employees         : Monthly \nVendors/Suppliers     : Quarterly/Half Yearly (as per borrower’s cash flow)'),
#   ('What are the processing charges for NUST Ujala Finance Application?',
#    'SE/ME/Vendor/Supplier'),
#   ('Domestic Borrower', 'NUST Employees'),
#   ('Is there any late payment charges?',
#    'In case of delay of installment, commercial rate will be charges on overdue days.'),
#   ('What are the service/documentation/legal charges in NUST Ujala Finance?',
#    'At actual'),
#   ('What are the insurance charges?', 'At actual')],
#  'NFMF': [('Is NUST Bank offering any seasonal financing?',
#    'Seasonal finance product "NUST Flour Mill Finance” has been structured through for quick financing under program-based lending. The product has been designed for Flour Mills in order to meet their working capital needs. NUST Flour Mill Finance caters to meet seasonal financing needs of wheat procurement and other overhead expenses to flour mills. The scope of product is to target flour mills which fall under category of SME.'),
#   ('For which purposes NUST Flour Mill Finance is being offered?',
#    'Cash Finance (CF)\nTo meet working capital requirements of flour mill business for procurement of wheat as per milling capacity'),
#   ('What are the Loan Limits of NUST Flour Mill Finance?',
#    'Per party (single entity) can avail up to Rs. 75M for ME and Rs. 25M for SE'),
#   ('Is there any minimum age to avail financing in NUST Flour Mill Finance?',
#    'Age of borrower (in case of sole-proprietorship) must be minimum 20 years, however age not to exceed 65 years at the time of application. This age can be relaxed in case of effective succession planning for business operations.'),
#   ('What is the maximum tenure of NUST Flour Mill Finance?',
#    'Maximum 1 year as per clean-up corridors'),
#   ('What is the current Mark-up rate of NUST Flour Mill Finance?',
#    'Cash Finance\n3 Months average KIBOR + 3% p.a.'),
#   ('Any Account turnover requirement for NUST Flour Mill Finance?',
#    'Minimum 50% of applicant’s sales to be documented through account turnover with bank(s).'),
#   ('What are the processing charges for NUST Flour Mill Finance Application?',
#    'Processing fee will be charged @ 0.15% of total limit(s) processed/approved or Rs. 25,000/- whichever is higher'),
#   ('What are the service/documentation/legal charges in NUST Flour Mill Finance?',
#    'At actual'),
#   ('What are the insurance charges?', 'At actual')],
#  'NFBF': [('Is NUST Bank offering any financing against liquid security?',
#    'NUST Fauri Business Finance” has been introduced to provide a swift package to meet financial business needs of new to bank obligor. AFBF is offered to meet short, medium and long-term requirements of business. The finance will be provided to SMEs & Commercial for all the eligible sectors as per NUST credit policy manual.'),
#   ('What is the Eligibility Criteria for business entity in Ask Fauri Business Finance?',
#    'All except individuals'),
#   ('Is there any business age requirement?', 'No'),
#   ('What is the nature of financing offered under Ask Fauri Business Finance?',
#    'AFBF-1:   Running Finance\nAFBF-2:   Term Loan\nAFBF-3:   Letter of Guarantee\nAFBF-4:   Letter of Credit – Sight / Usance'),
#   ('What is the current Mark-up rate of Ask Fauri Business Finance?',
#    'AFBF-1:  3MK /COD +1.50%\nAFBF-2:  12 MK /COD +2.0%\nAFBF-3:  As per SOC\nAFBF-4:  As per SOC'),
#   ('What is the principal repayment frequency in Ask Fauri Business Finance?',
#    'AFBF-1:  At Maturity\nAFBF-2:  Monthly / Quarterly\nAFBF-3:  Upon expiry / redemption\nAFBF-4:  Upon retirement'),
#   ('What is the markup repayment frequency in Ask Fauri Business Finance?',
#    'AFBF-1:  Monthly / Quarterly\nAFBF-2:  Monthly / Quarterly\nAFBF-3:  Upfront\nAFBF-4:  Upfront'),
#   ('What is the maximum tenure of Ask Fauri Business Finance?',
#    'AFBF-1:   Up to 1 Year\nAFBF-2:   Up to 3 Year\nAFBF-3:   Up to 30 Months\nAFBF-4:   At Sight / Usance period 120 days'),
#   ('What are the Loan Limits of Ask Fauri Business Finance?',
#    'Max Rs. 200 Mn (For all products)'),
#   ('Is there any grace period allowed in any financing?',
#    'Grace period of 3 months allowed for AFBF 2 (Term Loan Only)'),
#   ('In how many days the loan can be approved in Ask Fauri Business Finance?',
#    'Turnaround time (TAT) for disposal off the approval is fixed to 03 days from the date of pre-approval completion of documents'),
#   ('What is the collateral requirment for Ask Fauri Business Finance?',
#    '•\tNUST : Lien on NUST deposit CA/SA/ TDR, including 3rd party (LCY/FCY)\n•\tNational Saving Certificates (NSC): (Lien over NSC including joint name/owner)'),
#   ('What are the processing charges for Ask Fauri Finance Application?',
#    'Flat @ Rs. 3,000/- (at the time of initiating and on each renewal)'),
#   ('What are the service/documentation/legal charges in Ask Fauri Business Finance?',
#    'At actual'),
#   ('Is there any premature termination / Balloon payment charges?', 'Nil')],
#  'PMYB &ALS': [('Is NUST Bank Participating in PMYB & ALS?',
#    'NUST Bank is actively participating in PMYB&ALS. It has been specially designed to provide self-employment opportunity to the unemployed youth of the country who have skills, knowledge, experience or willingness to start their own businesses on small to medium scale or expand existing business on vast scale.'),
#   ('For which purposes PMYB & ALS is being offered?',
#    '•\tTo start new business \n•\tTo expand existing business'),
#   ('Nature of loans allowed in PMYB & ALS?',
#    '•\tLong term / Development Loans\n•\tWorking capital / Production Loans'),
#   ('What are the Loan Limits of PMYB & ALS?',
#    'Tier 2\n Above Rs. 0.5M and up to Rs 1.5M'),
#   ('Is there any minimum age to avail financing in PMYB & ALS and any mandatory qualification/experience required?',
#    'All Pakistanis aged between 21 and 45 are eligible to apply, however for IT/E-Commerce related businesses, the lower age limit will be 18 years (at least matriculation or equivalent education will be required)'),
#   ('What is the maximum tenure in PMYB & ALS?',
#    'Long Term Loan:  Maximum 8 Years (Maximum 1 Year Grace Period)'),
#   ('What is the current Mark-up rate of PMYB & ALS?',
#    'Tier 2\n     5% per annum'),
#   ('Does the bank require any Equity for this scheme?',
#    'Tier 2\n10% (New Business)'),
#   ('What is the repayment frequency in PMYB & ALS?',
#    'Repayment of PMYB&ALS loans will be made in the form of “monthly or quarterly Instalments (or as per SBP’s directives)'),
#   ('What is the security requirement for availing PMYB & ALS?',
#    'Tier 2\ni.\tClean; personal guarantee of the borrower\nii.\t02 Post Dated cheques for installment amount \niii.\t01 Post Dated cheque for full loan amount plus mark up as per amortization schedule'),
#   ('Is there any quota for womens?',
#    '25% of the loans will go to women borrowers'),
#   ('What are the processing charges for PMYB & ALS?', 'Rs. 100/-'),
#   ('What are the service/documentation/legal charges in PMYB & ALS?',
#    'At actual'),
#   ('Is there any late payment charges?',
#    'PKR 1,000/- plus FED per instance per installment, grace period included. (Late Payment to be triggered 15 days after installment becomes due i.e. on day 16)')],
#  'NRF': [('Is NUST Bank offering any seasonal financing for rice mills?',
#    'NUST Rice Finance caters to meet seasonal financing needs of paddy procurement and other overhead expenses to rice mills, based on past performance and milling capacity to fulfil their seasonal financial needs. The scope of the product is to target ‘Rice Mills’ which fall under the category of SME.'),
#   ('For which purposes NUST Rice Finance is being offered?',
#    'Cash Finance (CF)\nTo meet working capital requirements of Rice Husking Mills for procurement of paddy as per milling capacity.'),
#   ('What are the Loan Limits of NUST Rice Finance?',
#    'ME: Upto Rs.200M (Maximum)\nSE:   Upto Rs.25M (Maximum)'),
#   ('Is there any minimum age to avail financing in NUST Rice Finance?',
#    'Minimum 20 years (in case of sole proprietorship)\nMaximum 65 years at the time of application.\n\n* This criteria is not applicable if business concern is a partnership or limited company\n*This age can be relaxed in case of effective succession planning is available.'),
#   ('What is the maximum tenure of NUST Rice Finance?',
#    'Cash Finance\nMax 270 Days or Clean-up corridors whichever is earlier'),
#   ('What is the current Mark-up rate of NUST Rice Finance?',
#    'Cash Finance\n3 Months KIBOR + Up to 3.00% p.a'),
#   ('Any Account turnover requirement for NUST Rice Finance?',
#    'Minimum 50% of applicant’s sales to be documented through account turnover with bank(s).'),
#   ('What are the processing charges for NUST Rice Finance Application?',
#    'Processing fee will be charged @ 0.15% of total limit(s) processed/approved or Rs. 25,000/- whichever is higher'),
#   ('What are the service/documentation/legal charges in NUST Rice Finance?',
#    'At actual'),
#   ('What are the insurance charges?', 'At actual')],
#  'NHF': [('Is there any business loan product offered by NUST for families of armed forces and retired officers of the armed forces?',
#    'NUST Hunarmand Finance is a sub product of PMYB&ALS which is structured with an objective to provide business opportunity to specific target market.\n•\tRetired commissioned, junior commissioned, non-commissioned officers of the armed forces and their family members i.e. spouse and children\n•\tSpouse and children of serving commissioned, junior commissioned and non-commissioned officers of armed forces.'),
#   ('For which purposes NUST Hunarmand Finance is being offered?',
#    '•\tTo start new business \n•\tTo expand existing business'),
#   ('Nature of loan allowed in NUST Hunarmand Finance?',
#    '•\tLong term / Development Loans\n•\tWorking capital / Production Loans'),
#   ('What are the Loan Limits of NUST Hunarmand Finance?',
#    'Tier 2\n Above Rs. 0.5M and up to Rs 1.5M'),
#   ('Is there any minimum age to avail financing in NUST Hunarmand Finance?',
#    'All Pakistanis aged between 21 and 45 are eligible to apply, however for IT/E-Commerce related businesses, the lower age limit will be 18 years'),
#   ('What is the maximum tenure in NUST Hunarmand Finance?',
#    'Long Term Loan:  Maximum 8 Years (Maximum 1 Year Grace Period)'),
#   ('What is the current Mark-up rate of NUST Hunarmand Finance?',
#    'Tier 2\n4.5% per annum'),
#   ('Does the bank require any Equity for this scheme?',
#    'Tier 2\n10% (New Business)'),
#   ('What is the repayment frequency in NUST Hunarmand Finance?',
#    'Repayment of AHF loans will be made in the form of “monthly or quarterly Instalments (or as per SBP’s directives)'),
#   ('What is the security requirement for availing NUST Hunarmand Finance?',
#    'i.\tPersonal guarantee of borrower for loans up to 1.5M, and direct debit authority of borrower/pensioner/guarantor to be obtained\nii.\tFor loans above 1.5M, it shall be secured against movable as well as immovable assets of borrowers as defined under PMYB&ALs\niii.\tGuarantee of serving officer of armed forces in case of his family (spouse or children) avail loan under this program.'),
#   ('Are there any late payment charges?',
#    'Late payment charges PKR 1,000/- plus FED will be charges after 30th day of installment overdue.'),
#   ('What are the charges applicable for NUST Hunarmand Finance?',
#    'Applicable as per PMYB & ALS')],
#  'Nust Life': [('Can I purchase Bancassurnce policy from my account maintained with NUST Bank?',
#    'Yes, every customer who attain the age of 18 and have account with NUST Bank can eligible to purchse Bancassurnce policy from his account.'),
#   ('What are the main features of NUST Life Bancassurnace Policy?',
#    '-\xa0 Short term Family Protection and in Long term Savings'),
#   ('How many NUST Life  Insurance Plans available?',
#    'o\xa0\xa0 NUST Life Value Plan'),
#   ('What are the main features of these NUST Life Insurance Plans',
#    '- 14 Days Free Look Period start from the day customer received Policy Documents.')],
#  'EFU Life': [('Can I purchase Bancassurnce policy from my account maintained with NUST Bank?',
#    'Yes, every customer who attain the age of 18 and have account with NUST Bank can eligible to purchse Bancassurnce policy from his account.'),
#   ('What are the main features of EFU Bancassurnace Policy?',
#    '-\xa0 Family Protection and Long term savings'),
#   ('How many EFU Insurance Plans available?',
#    'o\xa0\xa0 EFU Savings and Protection Plan'),
#   ('What are the main features of these EFU Insurance Plans?',
#    '- 14 Days Free Look Period start from the day customer received Policy Documents.')],
#  'Jubilee Life ': [('Can I purchase Bancassurnce policy from my account maintained with NUST Bank?',
#    'Yes, every customer who attain the age of 18 and have account with NUST Bank can eligible to purchse Bancassurnce policy from his account.'),
#   ('What are the main features of JLI Bancassurnace Policy?',
#    '-\xa0 Short term Family Protection and in Long term Savings'),
#   ('How many Jubilee Life Insurance Plans available?',
#    'o\xa0\xa0 Jubilee Life Savings and Protection Plan'),
#   ('What are the main features of these Jubilee Life Insurance Plans',
#    '- 14 Days Free Look Period start from the day customer received Policy Documents.')],
#  'HOME REMITTANCE': [('What is Home Remittance ?',
#    'Home Remittance Service enables remitters to send money from abroad to Pakistan instantly, conveniently, and safely through the legal banking channel.'),
#   ('What types of Inward Home Remittance products does NUST Bank offer ?',
#    'NUST  offers the following Home Remittance Products to cater to the needs of various home remittance\nbeneficiaries in Pakistan:\n• Cash Over the Counter (CoC) payments for walk-in customers\n• NUST Account Transfer\n• Other Bank Account Transfer via Inter Bank Funds Transfer (IBFT) & Real Time Gross Settlement (RTGS)'),
#   ('In which currency will I receive my remittance?',
#    'All home remittance payments are disbursed in Pak Rupees.'),
#   ('Is there any limit on the amount received though NUST Home Remittance?',
#    'Below are the applicable limits:\n• NUST Accounts - No Limit\n• Other banks accounts - No Limit\n• Cash Over the Counter (CoC) Transactions - Up to PKR 1,000,000/- per transaction and there is no limit of Western Union COC transactions'),
#   ("Are there any charges/fee for NUST's Home Remittance Service?",
#    'NUST Home Remittance Service is free of charge.'),
#   ('Are there any tax deductions on Home Remittances?',
#    'Home Remittance Service is free of taxes.'),
#   ('Can I receive remittance in Pakistan if I do not have a bank account with any bank?',
#    'You can receive your home remittance from any of NUST 600+ domestic branches nationwide if you have a valid CNIC and Transaction Unique Reference No. / Pin code.'),
#   ('Is there any list of branches I can access to get information?',
#    'The list of NUST domestic branches can be viewed from the Branch Locator available on our corporate website www.nustbank.com .'),
#   ('Who should I contact in case I need to lodge a complaint regarding Home Remittance?',
#    'For any query/complaint regarding Home Remittance, you may contact our dedicated Remittance Service Centre at UAN# 021-111-000-787. \nYou may also email your queries/complaints at remittance@NUSTbank.com.pk'),
#   ('How can I obtain a Proceed Realization Certificate (PRC)/Encashment Certificate against remittance(s) received? Who should I contact?',
#    'Please find below contact details for obtaining a PRC and e-PRC:\n •  e-PRC option is also available at the NUST website https://secureportal.NUSTbank.com/eprc/customer to obtain a system generated PRC on your registered email address.                                                                                                                                                                                                                                                                         \n • Proceeds Realization Certificate (PRC) is issued from NUST Centralized Remittance Department. You may contact them at the following email addresses:\nremittance.prc@NUSTbank.com.pk'),
#   ('Can I track my remittance status online?',
#    'Yes, you can view the status of your remittance online through NUST Remittance Tracker by following link https://NUSTbank.com/services/alternate-delivery-channels/home-remittance-tracking/'),
#   ("What are NUST's Banking hours to avail home remittance services from NUST Branches?",
#    'Customers can avail home remittance services from NUST domestic branches during regular business hours appended below:\n• Monday to Thursday: 09:00 am to 05:00 pm\n• Friday: 09:00 am to 05:30 pm\n• Saturday: 09:00 am to 01:30 pm (through selected branches)'),
#   ('Is it important to declare the purpose of the funds being sent to Pakistan?',
#    'Yes, it is mandatory to provide purpose of funds being sent to Pakistan.'),
#   ('I am a foreign national, can I send money to Pakistan?', 'Yes, you can.'),
#   ('Does the PRI comes under the laws of State Bank or Government?',
#    'It is a joint initiative of  State Bank of Pakistan, Ministry of overseas Pakistanis and Ministry of Finance.'),
#   ('Can the Freelance payment  be made through PRI?',
#    'Yes Freelance payments is allowed under specfic arrangemnts with Tie-ups with allowed purposes as per SBP guidelines.'),
#   ('What conversion rates will be applied on remittance?',
#    'The same conversion rates will be applied at the time of sending the remittance. Affiliated bank or Exchange Company confirm the Conversion rates to Sender at the time of sending the remittance.'),
#   ('Does NUST Bank has specialized remittance Account as per SBP guideline?',
#    'Yes NUST has remittance account name as Pak Wattan Remittance Account.'),
#   ('Who can open Pak Wattan Remittance Account?',
#    'A Bonafide recipient of Home remittance (PRI) can open this account.'),
#   ('Can remittance be sent from anywhere to Pakistan?',
#    'Yes, remittance can be sent from around the globe to Pakistan through our agent Partners like Western Union, Mastercard, Dandelion Payments (RIA) etc. \nFor more information please go through the below link:')]}

# %%
for sheet, qa_list in qa_dict.items():
    print(f"\nSheet: {sheet}")
    for q, a in qa_list:
        print("Q:", q)
        print("A:", a)
# Out:
# Sheet: Main
#
# Sheet: Rate Sheet July 1 2024
#
# Sheet: LCA
# Q: I would like to open an account with my son, do u have any product for kids?
# A: Yes our product is Little Champs Account. It is designed specifically for minors (individuals below the age of 18 years). A child requires the help of a parental/legal guardian to open this account and avail its facilities. Little Champs get a Debit Card and chequebook which is free the first time
# Q: What are the main Features  of the Little Champs Account.
# A: Minimum initial deposit of Rs.100/-
# Q: What other Value added features does the Little Champs Account have?
# A: Attractive returns on savings account
# Q: What is the account type of Little Champs Account is it saving or current ?
# A: This account is offered both in current and savings categories
# Q: How can the minor operate this account?
# A: This account is opened in the name of the minor. However, a minor needs a guardian’s help to avail the account’s facilities
# Q: What documents are required to open a Little Champs Account.
# A: ·        A photocopy of Form-B, Birth Certificate or Student ID card (as appropriate) of the minor
#
# Sheet: NAA
# Q: What is the Eligibility Criteria for NAA?
# A: Resident Pakistani individuals who do not maintain/have any other account (single or joint) in NUST Bank Limited are eligible to open the NAA in Pak rupees as a single/joint account.
# Q: What is the account type of NAA?
# A: NAA can be opened both in Current & Savings
# Q: What is the opening and minimum balance requirement in NAA?
# A: Account can be opened with Rs.100/ and there is No minimum balance requirement.
# Q: What are the basic Features  of NUST Asaan Account?
# A: o Bi-annual account statements
# Q: What is the Profit rate on NAA Savings account?
# A: Current profit rate is 20.50% which is paid Semi Annually.
#
# Sheet: NWA
# Q: Does your bank offer any account for senior citizens?
# A: NUST Waqaar Account has been developed for senior citizens, enabling them to carry out their banking transactions and also to avail investment opportunities.
# Q: What are the salient features of NUST Waqaar Account ?
# A: Tenure
# Q: What identity documents are required to open NUST Waqaar Account?
# A: A photocopy of any one of the following valid identity documents:
# Q: What is the minimum age to qualify for opening of  NUST Waqaar Account & Minimum deposit requirement ?
# A: Minimum age to qualify is 55 years
# Q: What is the minimum deposit requirement to open NUST Waqaar Savings Account & NUST Waqaar Term Deposit?
# A: - Minimum deposit for opening of the NUST Waqaar – Savings account is Rs.1,000
#
# Sheet: PWRA
# Q: Is there any account NUST Bank is offering for remittance purposes ?
# A: Yes PakWatan Remittance Account.
# Through the PakWatan Remittance Account, beneficiaries can quickly and securely receive remittances from their loved one living abroad directly into their bank account without visiting the branch.
# Q: What are initial/minimum balance requirements for PakWatan Remittance Account?
# A: No initial deposit requirement
# Q: Are Local Credits allowed in PakWatan Remittance Account?
# A: Local credits are also allowed in PakWatan Remittance Account
# Q: What are the free services associated with PakWatan Remittance account?
# A: Free services include:
# Q: Are there any other benefits to opening a PakWatan Remittance Account?
# A: o  WHT exemption on cash withdrawal on home remittances received from abroad
# Q: Is there any Insurance Coverage for this account?
# A: o   ATM Cash Withdrawal Insurance coverage up to daily cash withdrawal limit of the debit card from NUST Bank ATMs
# Q: What is the profit rate offered on this account and when is credited?
# A: Profit payment on monthly basis based on monthly average balance
#
# Sheet: RDA
# Q: Does NUST Bank offer Any account for Non-Resident Pakistanis (NRPs)?
# A: Yes Roshan Digital Account. Specially Designed for Individual Non-Resident Pakistanis (NRPs) seeking to undertake banking, payment and investment activities in Pakistan.
# Q: Is there any minimum balance requirement of Roshan Digital Account?
# A: No initial deposit requirement
# Q: What are the main features of the Roshan Digital Account?
# A: Offered in PKR and USD/GBP/EUR
# Q: What are the free facilities ?
# A: Free First Issuance of Debit Card- Annual charges as per prevailing SOC
# Q: How to apply for Roshan Digital Account ?
# A: Customer can visit NUST Bank’s website and click on "Apply for Roshan Digital Account" to open NUST Roshan Digital Account. ◦
# Q: What is the NUST Bank Web Portal Link for RDA?
# A: https://secureportal.NUSTbank.com/rda/
# Q: Who can open a Roshan Digital Account?
# A: NRPs
#
# Sheet: VPCA
# Q: I would like to inquire about opening a current account for Individuals with your Bank. Please tell me what options I have ?
# A: NUST Value Plus Current Account is specially designed for individuals to cater their financial needs.
# Q: What are the free facilities being provided with NUST Value Plus Current Account?
# A: - Cheque Books (unlimited)
# Q: Are there any insurance benefits associated with VPCA'?
# A: - ATM Cash Withdrawal Insurance Coverage
# Q: What is the opening and minimum balance requirement for VPCA?
# A: - No Opening Balance Requirements
#
# Sheet: VP-BA
# Q: I would like to inquire about opening a current account for business with your Bank. Please tell me what options I have?
# A: NUST Value Plus Business Account is best suited for startups and businesses
# Q: Please tell me about  Free Facilities being provided on Value Plus Current Account for Business upon maintaining minimum Monthly average Balance ?
# A: Issuance of Cheque Books
# Q: Issuance of Debit Card*
# A: Internet Banking facility
# Q: Please tell me about  minimum Monthly balance required ?
# A: No initial deposit requirement
# Q: What is Target Market for  Value Plus Business Account ?
# A: Sole Proprietors
# General Partnership
# Small Enterprises
# Q: Is there any insurance coverage available?
# A: ATM Cash Withdrawal Insurance
# Speedy processing of SBP Kamyab Jawan loans
#
# Sheet: VPBA
# Q: I would like to inquire about opening a current account for business purpose with your Bank. Please tell me what options I have?
# A: NUST Value Premium Business Account has been designed to better meet the specialized banking needs of businesses that continue to grow with time.
# Q: Please tell me about  Free Facilities being provided on Value Plus Current Account for Premium Business  upon maintaining minimum Monthly average Balance?
# A: Issuance of Cheque Books*
# Q: Issuance of Debit Card*
# A: Internet Banking facility
# Q: Please tell me about  the Minimum Monthly balance required for this account?
# A: No initial deposit requirement
# Q: What other benefits do I get from using a VPBA?
# A: Speedy processing of Financing
# Q: What is the Target Market for Value Plus Premium Business Account ?
# A: Medium Enterprises
#
# Sheet: NSDA
# Q: Is NUST Bank offering any account which provides lucrative profits on my savings?
# A: NUST Special Deposit Account (ASDA) is specially designed for large ticket customers to meet  their transactional and savings needs.
# Q: What is the minimum balance requirement of NUST Special Deposit Account?
# A: No Minimum Monthly Average Balance Requirement
# Q: Please tell me about profit payment and calculation?
# A: Profit Payment Frequency- Monthly
# Q: What are the free services available with ASDA?
# A: Free E-statement & I-Net Banking
# Q: What is the Target Market?
# A: HNW Individuals (either singly or jointly)
#
# Sheet: PLS
# Q: Is your bank offering Profit & Loss account ?
# A: Yes, Profit & Loss Sharing Account is specially designed to meet the transactional and savings need of customers.
# Q: What are the main features of NUST Profit & Loss Sharing (PLS) Account?
# A: Offered in LCY (PKR) & FCY (USD, GBP, EUR, JPY & AED)
# Q: What are free features available with NUST Savings Profit & Loss Sharing (PLS) Account.
# A: Free E-statement & I-Net Banking
# Q: What is the Target Market?
# A: Individuals (either singly or jointly)
#
# Sheet: CDA
# Q: Is your bank offering any Current Deposit account ?
# A: Current Deposit Account is specially designed for customers with regular banking transactional needs and do not need Profit.
# Q: What are the main features of Current Deposit Account?
# A: Offered in LCY (PKR) & FCY (USD, GBP, EUR, JPY & AED)
# Q: What are the free services offered with Current Deposit Account?
# A: Free SMS alerts facility on Digital Transactions
# Q: What is the target market for Current Deposit Account?
# A: Individuals (either singly or jointly)
# Proprietorship Concerns, Business Owners
# Partnership Firms
# Public and Private Limited Companies
# Government Organizations
# Corporations, Clubs, Societies, NGOs etc.
#
# Sheet: NMA
# Q: Is there any account which provides lucrative profits on my long term savings?
# A: Yes, NUST Maximiser Account has been designed to fulfill your basic banking needs and provide lucrative profit on your savings.
# Q: What are the main Features of NUST Maximiser Savings Account?
# A: -  Attractive profit payment on monthly, quarterly, semi-annual & annual basis:
# Q: What are the free services available with NUST Maximiser Savings Account?
# A: o   Bankers Cheque Issuance
# Q: What are main Features of NUST Maximiser Term Deposit
# A: - Tenure: 1, 2, 3 & 5 Years
# Q: Is there any Premature Encashment Penalty in NUST Maximiser Term Deposit?
# A: The encashment of NUST Maximiser Term Deposit before maturity will be subject to premature encashment penalty as below:
#
# Sheet: NADA
# Q: Is NUST Bank offering a simple Digital Banking Account  ?
# A: Yes, NUST Asaan Digital Account is being offered
# Q: What is the Target  Market of NUST Asaan Digital Account ?
# A: NUST Asaan Digital Account is specially designed for unbanked / under-banked customer segments. This account is most suited for but not limited to skilled/unskilled workforce
# Q: What is the Account type of NUST Asaan Digital Account ? is it Current or Saving?
# A: NUST Asaan Digital account is a Current Account in PKR currency
# Q: What are the free benefits of NUST Asaan Digital Account ?
# A: Free Issuance of First Cheque book (25 Leaves)*
# Q: Who is eligible for this account?
# A: Skilled/Unskilled Workforce
# Q: Is there a Monthly Transaction Limit (Debit  and Credit Limit) in NUST Asaan Digital Account ?
# A: Maximum Credit Balance Limit  PKR 1,000,000/-
#
# Sheet: NADRA
# Q: I would like to inquire about opening of a Digital Remittance Account, Please tell me what options are available?
# A: NUST Asaan Digital Remittance Account is specially designed for Pakistani Resident Individuals who wish to receive remittances from their families and friends living abroad, directly in a bank account without the hassle of visiting the branch.
# Q: What is the Account type of NUST Asaan Digital Remittance Account ? is it Current or Saving?
# A: NUST Asaan Digital Remittance account is a Current Account in PKR currency
# Q: What are the free benefits of NUST Asaan Digital Remittance Account ?
# A: Free Issuance of First Cheque book (25 Leaves)*
# Q: What is the Target Market?
# A: Individuals- Beneficiaries (families) of Pakistanis working abroad
# Q: Are there any transaction limits in NUST Asaan Digital Remittance Account ?
# A: The following Transaction limits apply:
#
# Sheet: NUST4Car
# Q: 1.What are the benefits of NUST Bank Auto Finance?
# A:
# Q: 2. Who can apply for NUST Auto Finance?
# A: ·        Salaried Individuals
# Q: 3. Which types of Vehicles are offered under NUST auto finance?
# A: Locally assembled/manufactured
# Q: 4. Can I avail Loan Facility, if there are defaults against my previous loan(s)?
# A: No. Regular payment against previous loans is necessary.
# Q: 5. How much loan can I avail?
# A: Up to a maximum of Rs.3 Million from all banks/DFIs in aggregate, subject to a maximum of 40% Debt Burden requirement.
# Q: 6. What is maximum period of loan?
# A: Up to 1000 CC Vehicles                                       up to 5 Years
# Q: 7. How much Equity/Down Payment is required?
# A: Minimum 30%  equity +(1st Year Insurance + documentation charges) is required as down payment
# Q: 8. Can I avail more than one vehicle through Auto loan facility?
# A: Yes. Two vehicles can be availed simultaneously from NUST Bank, subject to Debt Burden Limitations
# Q: Professional?
# A: Yes. The individual  with  foreign remittance, supported by Bank statement  and remittance receipts can avail Auto Loan Facility
# Q: 10. Are there any hidden charges?
# A: There are no hidden charges. All charges are mentioned in our Schedule of Charges available at our website and at all branches of NUST Bank.
# Q: 11. Is insurance of vehicle is mandatory?
# A: Yes. Comprehensive Insurance of vehicle is mandatory for the whole tenor of loan at the cost of the borrower
# Q: 12. What will be the monthly insurance charges on the vehicle valuing Rs.3 million?
# A: With the current insurance rate of 1.75% per annum, it will be Rs.4,375/- per month.
# Q: 13. Who will insure my Vehicle?
# A: NUST Bank has insurance arrangements with reputed insurance companies with attractive insurance rate,
# Q: 14. Can I pay my loan before maturity?
# A: Yes. You can pay your loan before maturity. However, charges shall be applicable as per prevailing SOC
# Q: 15. What is the security against the loan?
# A: Financed vehicle will be the security against the loan, which will be hypothecated in favour of NUST Bank.
# Q: 16. Whether bank is responsible for delay in booking or delivery of vehicle?
# A: No. Bank does not assume any responsibility in this regard, as same is beyond the control of bank.
# Q: 17. Whether bank is responsible for any type of dispute related to Warranty/Fault in vehicle/Service issues with Dealership or vehicle Manufacturer?
# A: No. Bank does not assume this responsibility. Customer will take up the matter directly with dealership or manufacturer.
# Q: 18. What is the Loan Application processing time?
# A: The processing time for loan approval is approximately 11 working days, subject to complete application with required documents/formalities.
# Q: 19. How can I apply for loan?
# A: You can apply by visiting any of our  Branch or by calling us at 24 hours Contact Centre at 111-000-787.
#
# Sheet: ESFCA
# Q: Does NUST Bank offer a Digital Banking Account for Freelancers ?
# A: NUST Freelancer Digital Account is exclusively designed for Freelancers, so that they can receive their payments directly in a bank account and enjoy other lifestyle banking services as well.
# Q: What is the Account type of NUST Freelancer Digital Account ? is it Current or Saving?
# A: NUST Freelancer Digital Account offered Current Account in PKR & FCY (USD, GBP, EUR, AED)
# Q: What are the free benefits of NUST Freelancer Digital Account?
# A: Free Issuance of First Cheque book (25 Leaves)*
# Q: What is the Target Market?
# A: Individuals running a freelance service business
# Q: Are there any Credit and Debit limits in NUST Freelancer Digital Account?
# A: The following Transaction limits apply:
#
# Sheet: NFDA
# Q: Does NUST Bank offer a Digital Banking Account for Freelancers ?
# A: NUST Freelancer Digital Account is exclusively designed for Freelancers, so that they can receive their payments directly in a bank account and enjoy other lifestyle banking services as well.
# Q: What is the Account type of NUST Freelancer Digital Account ? is it Current or Saving?
# A: NUST Freelancer Digital Account offered Current Account in PKR & FCY (USD, GBP, EUR, AED)
# Q: What are the free benefits of NUST Freelancer Digital Account?
# A: Free Issuance of First Cheque book (10 Leaves)*
# Q: What is the Target Market?
# A: Individuals running a freelance service business
# Q: Are there any Credit and Debit limits in NUST Freelancer Digital Account?
# A: The following Transaction limits apply:
#
# Sheet: NSA
# Q: Is NUST Bank offering any account specifically for Women?
# A: - Yes! NUST Bank Offers NUST Sahar Account.
# Q: What is the account type of NUST Sahar Account?
# A: NUST Sahar Deposit suite consists of following variants:
# Q: What are the free facilities NUST is offering on NUST Sahar Current Account ?
# A: ·        First Cheque Book
# Q: Can we open this account online?
# A: ·        Digital account opening facility available with account opening within 48 hours
# Q: Does the bank offer option of Term Deposits with this account.
# A: ·        Yes, Option to book exclusive NUST Sahar Term Deposits from NUST Sahar Current Account at attractive rates is available.
# Q: Is there a Minimum balance requirement for NUST Sahar Current Account
# A: ·        No minimum average balance requirement for account maintenance
# Q: What is the profit payment system for NUST Sahar Savings Account ?
# A: ·        Monthly Profit Payment
# Q: What are the free services offered on NUST Sahar Savings Account?
# A: ·        First Debit Card Issuance*
# Q: What are the main features of NUST Sahar Term Deposit ?
# A: ·        Flexibility to choose from multiple tenure: 1, 3 or 5 Years
# Q: What is the Premature Encashment Penalty on NUST Sahar Term Deposit ?
# A: - The encashment of NUST Sahar Term Deposit before maturity will be subject to premature encashment penalty as below:
# Q: What is the initial deposit requirement of NUST Sahar Asaan Current Account?
# A: - Rs. 100 only
# Q: What are the main features of NUST Sahar Asaan Current Account ?
# A: - Simplified Account Opening with single pager Account Opening form & CNIC
# Q: Is there any Transaction Limitation for NUST Sahar Asaan Current Account ?
# A: - Monthly withdrawal limits up to Rs. 1,000,000
# Q: What are the free services offered on NUST Sahar Asaan Current Account ?
# A: - Free Inter Branch Online Cash Deposit/Withdrawal (Online)
#
# Sheet: PF
# Q: Who can apply for NUST Personal Finance?
# A: 1· Armed Forces Officers
# 	 - Serving employees
# 	 - Retired employees
#
# 2.	JCOs/Equivalent & Lower Cadres
# 	 - Serving employees
# 	 - Retired employees
#
# 3.	Allied Armed Forces (SPD & its allied concerns) and Civilians (in GHQ/NHQ & AHQ)
# 	 - Serving employees (Permanent & Contractual Employees)
#
# 4.	Fauji Foundation Group
# 	 - Permanent employees
# 	 - Contractual employees
# Q: Can overseas Pakistanis obtain Personal Finance facility from NUST?
# A: No, the availability of applicants & their employers is mandatory within Pakistan for applying clean Personal Finance.
# Q: What is the minimum and maximum financing amount?
# A: The minimum financing amount is Rs. 50,000/ (Rs. 35,000 for retired JCOs & Lower Cadre - Subject to pension with NUST).
# Q: What are the minimum & maximum financing tenures?
# A: Minimum 01 year
# Q: What is the age criteria for applying NUST Personal Finance?
# A: Minimum:
# Salaried:  21 years (18 years for Armed Forces)
# SEB/SEP:  23 years
# Prime Customers:  25 years
# Q: What is the minimum monthly income criterion?
# A: Salaried (Approved Company):
#  - Category A Company - PKR 40,000 (Permanent) & PKR 60,000 (Company / 3rd Party Contractual)
#  - Category B & C Company - PKR 50,000 (Permanent) & PKR 60,000 (Company / 3rd Party Contractual)
#
# Salaried (Non-approved Company):
#  - PKR 70,000 (Permanent) & PKR 80,000 (Company Contractual)
#
# Salaried (GOP):
#  - Serving - PKR 35,000 (Permanent, BPS-5 & above) & PKR 45,000 (Contractual)
#  - Retired - PKR 40,000 subject to pension with NUST
# Q: In which area of the country one can avail Personal Finance form NUST?
# A: Personal Finance can be availed from all cities where NUST branches exists.
# Q: What is the Application processing time?
# A: The processing time of Personal Finance is 10 working days form login till approval (subject to complete application with required documents).
# Q: What is the Application processing Charges?
# A: It will be as per prevailing Schedule of Charges (SOC) or As per corporate arrangement.
# Q: What is the repayment mode?
# A: Payment of Equal Monthly Instalment (EMI) comprising of principal, mark-up and insurance payment will be made through Direct Debit Authority (DDA) of borrower’s account maintained with NUST.
# Q: Can I make balloon payments or premature termination of facility?
# A: Yes, Balloon payment or premature termination option is available for all customers.
# Charges will be applied as per prevailing Bank’s schedule of charges / As per corporate arrangement.
# Q: What happens if I fail to fulfil your payment obligations?
# A: In case of overdue / default, recovery department of NUST will contact you, your loan related details will be reported to Credit Bureau.
# Q: How will I get update of my Personal Loan Application?
# A: You can visit/ call or send email at our Customer Services centre(s) as well.
#
# Sheet: NMC
# Q: 1.Who can apply for NUST Credit Card Facility?
# A: Salaried Individuals
# Q: 2.What is the minimum age for applying NUST Mastercard Credit Card?
# A: Minimum 21 years old & Pakistani resident, can apply for NUST MasterCard Credit Card.
# Q: 3. What is the maximum age for applying NUST Mastercard Credit Card?
# A: Salaried (Permanent):  60 years
# Q: 4.Can overseas Pakistanis obtain Credit Card facility from NUST?
# A: Yes. The individuals maintaining FC account with NUST, Remittances/ Roshan Digital Account holders/
# Q: 5. What is the minimum and maximum financing amount?
# A: Clean facility, Minimum Rs. 30,000/- and maximum up to 3.0 Million or as per 40% Debt Burden Ratio subject to SBP PRs.
# Q: 6. What would be the financing tenure?
# A: NUST Credit Card is an Evergreen facility & renewable after expiry of credit card.
# Q: 7. What is the minimum monthly income criterion?
# A: GOP / Semi Govt. / Autonomous Bodies etc: Permanent, Rs. 35,000/- Contractual, Rs. 45,000/-
# Q: 8. In which area of the country one can avail Credit Card facility?
# A: Credit Card can be availed from all cities / Areas without discrimination
# Q: 9. What is the Application processing time?
# A: The processing time of Credit Card facility is 10 working days form login till approval subject to complete application with required documentation
# Q: 10. What are the Application Processing Charges?
# A: Processing Charges will be as per prevailing Bank’s Schedule of Charges (SOC).
# Q: 11. What happens if I fail to fulfil your payment obligations?
# A: In case of overdue / default, recovery department of NUST will contact you, your loan related details will be reported to Credit Bureau. Late payment and cheque return charges may also be applicable as per prevailing schedule of charges. Legal proceeding may also be initiated by the Bank.
# Q: 12. How will I get update of my Credit Card Application?
# A: You can visit/ call or send email at our Customer Services centre(s) as well. Services centre(s) as well.
# Q: 13. Is there a limit to international Spending?
# A: As per SBP directives i.e. Nov 1, 2022 industry-wide annual maximum limit of USD 30,000/- per individual on card-based
#
# Sheet: NMF
# Q: 1.What types of Housing Finance products does NUST offer?
# A: Purchase of House/ Apartment/ Flat/ Residential Unit
# Q: 2.What is the minimum age for applying NUST Mortgage Finance?
# A: Salaried : 21 Years
# Q: 3. What is the Maximum age criteria for applying NUST Mortgage Finance?
# A: Salaried Permanent : 60 Years at the maturity of loan
# Salaried Contractual: 65 Years at the Matrurity of loan
# Pensioners: 65 Years at the maturity of loan
# SEB/SEP: 65 Years at the maturity of loan
# Q: 4.Can overseas Pakistanis obtain House Finance facility from NUST?
# A: Yes. However can apply as Co-Borrower with veriable income. Basic borrower from Pakistan should also meet the required basic criteria for MF.
# Q: 5. What is the minimum and maximum financing amount?
# A: The minimum financing amount is Rs. 500,000/.
# The maximum financing limit will be up to Rs.100,000,000/- subject to 50% Debt Burden Ratio(DBR) as per SBP PRs for Housing Finance.
# Q: 6. What would be the financing tenure?
# A: Loan tenure is Minimum 3 years and maximum 25 years
# Q: 7. Can I obtain financing on my owned property by mortgaging it?
# A: Yes, purpose of finance has to be in line with the purpose defined by regulator i.e.
# Q: 8. Can I avail more than one House loan?
# A: Yes. One can avail two Mortgage Loans at a time from NUST Bank within Debt Burden Ratio (DBR) as per prevailing SBP PRs for Housing Finance.
# Q: 9. Can I avail income tax rebate on House Financing?
# A: Yes, one can claim tax rebate against its House Finance mark-up paid during the year, or as per prevailing Tax laws of the country.
# Q: 10. What is the minimum monthly income criterion?
# A: Salaried: Permanent Rs. 50,000/-, Contractual Rs. 60,000/-, Govt. Employee Contractual 75,000/-
# Q: 11. Can I club income of Co-Borrower?
# A: Yes. Clubbing of Co-Borrower income may be allowed in case of spouse/son/parents/un-married daughter/Sibling.
# Q: 12. What are the processing charges for NUST Mortgage FInance?
# A: Processing Charges will be as per prevailing Bank’s Schedule of Charges (SOC).
# Q: 13. What is the repayment mode?
# A: Payment of Equal Monthly Installment (EMI) comprising of principal, mark-up and Insurance cost etc. will be made through Direct Debit Authority (DDA) of borrower’s account maintained with NUST.
# Q: 14. Is Property insurance coverage mandatory?
# A: Yes. Property Insurance is mandatory; Insurance premium is born by the borrower. It covers construction cost of financed house and value of property in case of apartment.
# Q: 15. Can I make balloon payments or premature termination is allowed?
# A: Yes, Balloon payment or premature termination option is available for all customers. Charges will be applied as per prevailing Bank’s schedule of charges.
# Q: 16. Can the loan amount be used for any other purpose?
# A: No, the loan amount can only be used for specific purpose i.e.
# Q: 17.In which area of the country one can avail House Finance form NUST?
# A: Mortgage Finance facility can be availed from all cities / areas without discrimination.
# Q: 18. Where financing is not allowed?
# A: The financing shall not be allowed for;
# Q: 14. What is the Application processing time?
# A: The processing time of Mortgage Finance is 30 days form login till approval subject to complete application with required documents.
# Q: How will I get update of my House Loan Application?
# A: Our Sales/ front end staff is quite supportive and always there to serve you. You can visit/call or send email at our Customer Services center(s) as well.
#
# Sheet: NSF
# Q: Is NUST Bank offering any financing specifically for women owned small and medium enterprises?
# A: The Product "NUST Sahar Finance" is based on Refinance and Credit Guarantee Scheme for Women Entrepreneurs objective of this product is to provide financing facilities to women owned enterprises to meet credit needs of their businesses.
# Q: What are the purposes for which NUST Sahar Finance can be availed?
# A: i. Expansion of existing business
# ii. Set up of new business
# iii.Purchase of stocks/ Working Capital Requirement etc
# Q: What is the applicant legal structure of business in order to avail NUST Sahar Finance?
# A: Sole Proprietor, Partnership Firm, Private Limited Company, Single Member Company (SMC), Business Individuals (Women Owned)
#
# *In Partnership firm/ Private Limited Company, having 02 partners or directors, minimum 51% shareholder/ CEO should be a a femle who should also be the applicant. If there are more than 02 partners or directors, major share holder should be women , who should also be CEO and applicant
# Q: What is the nature of finance in NUST Sahar Finance?
# A: i. Long Term Finance
# ii. Short Term Finance/Working Capital
# Q: What is the maximum tenure of NUST Sahar Finance?
# A: Short Term Finance/Working Capital
# Maximum 3 years with no grace period
# Q: Is there any age criteria to avail NUST Sahar Finance?
# A: New Business
# Between 20-50 years at the time of application
# Q: What are the Loan Limits of NUST Sahar Finance?
# A: New Business
# Maximum Loan Rs: 3.00 Million
# Q: What is the current Mark-up rate of NUST Sahar Finance?
# A: Mark-up Rate of @5% p.a.
# *Markup at 12M Kibor + 4% Per Annum to be charged till refinance claim reimbursed by SBP.
# Q: Can applicant avail clean loan in NUST Sahar Finance?
# A: Max Rs: 0.70 million can be availed against personal and third party guarantee
# Q: Does the bank require any Equity for this scheme?
# A: New Business
# 20% equity.
# Q: Is there any minimum business age requirement?
# A: Existing Business Should be women owned enterprises with Minimum 01 year of business registration
# New Business: Nil
# Q: What are the processing charges for NUST Sahar Finance Application?
# A: Up to Rs. 0.70
# Q: Are there any late payment charges?
# A: Rs. 1,000/- per installment
# *In case of delay of installment, commercial rate will be charged on the outstanding principal amount.
# Q: What are the service/documentation/legal charges in NUST Sahar Finance?
# A: At actual
# Q: What are the insurance charges?
# A: At actual
#
# Sheet: NIF
# Q: Is NUST Bank offering any financing specifically for the ownership & capacity enhancement of business premises?
# A: NUST Bank has structured a new financing product “NUST Imarat Finance” under the ambit of SME segment. The Product Program has been developed in order to stabilize SME business through making their ownership of business premises (under mortgage finance of urban commercial / industrial buildings) for capacity enhancement of SMEs.The product has been structured for SMEs owned by general public as well as retired armed forces officers and families of serving officers.
# Q: For which purpose NUST Imarat Finance is being offered?
# A: AIF 1:   Acquisition / Purchase of urban commercial / industrial construted property/ office and commercial premises for commercial / business activity
# AIF 2:   Construction on self owned urban commercial / Industrial plot
# AIF 3:   Additional construction on already built urban commercial/ industrial plaza/building
# AIF 4:   Renovation of self owned urban commercial /industrial property/Plaza/ business premises
# Q: What are the Loan Limits of NUST Imarat Finance?
# A: AIF 1:   Mininum Rs. 5.00 M & Maximum Rs. 100M
# AIF 2:   Mininum Rs. 5.00 M & Maximum Rs. 50M
# AIF 3:   Maximum Rs. 30M or upto 30% of FSV of offered property, whichever is lower
# AIF 4:   Maximum Rs. 5M or upto 25% of FSV of offered property, whichever is lower
# Q: What is the maximum tenure of NUST Imarat Finance?
# A: AIF 1:  Maximum 10 Years (Grace Period upto 6 months)
# Q: Does the bank require any Equity for this scheme?
# A: AIF 1 & AIF 2: Minimum 30%  (Existing business) & Minimum 40% (New Business)
# AIF 3 & AIF 4 : Nil for Existing business & Minimum 25% (New Business)
# Q: Is there any minimum age to avail financing in NUST Imarat Finance?
# A: New Business
# Minimum 30 years at the time of application, however age not to exceed 60 years at maturity of loan.
# Q: Any mandatory qualification/experience required?
# A: Specifically for New Business:
# i)	Only Professionals i.e. Chartered Accountants, Doctors, Engineers, IT Professionals, and consultants etc, with minimum 02 years professional experience.
# ii)	Retired professionals from armed forces and families of serving armed forces officers
# Q: What is the current Mark-up rate of NUST Imarat Finance?
# A: General Regular SME’s
# End-user Rate: 12MK+4% p.a. (to be reviewed on annual basis)
# Q: Is there any business age requirement?
# A: Existing Business Minimum 03 year operating history of business
# Q: What should be the legal structure of business for availing  NUST Imarat Finance?
# A: Sole Proprietor, Partnership Firm(registered), Private Limited Company, Limited Company
# Q: What is the security requirement for availing NUST Imarat Finance?
# A: i.	Effective Mortgage (Equitable / or token registered) to be created on same urban Commercial / Industrial property which has been financed
# ii.	03 post dated cheques of the full loan amount plus markup
# iii.	Personal Guarantees from borrowers, all partners and directors of the companies alongwith “Personal Net worth Statement”.
# iv.	Fard based property to be registered equivalent to the full loan amount
# Q: What is the repayment frequency in NUST Imarat Finance?
# A: Monthly/Quarterly
# Q: Is there any condition related to bank account maintenance for availing NUST Imarat Finance?
# A: Minimum 01 year bank account statement with NUST
#                                        Or
# Minimum 02 years bank statement with any other bank
# Q: Is there any penalty charges related to Premature termination/balloon payment penalties?
# A: Mode of Pre-Mature termination
# Q: What are the processing charges for NUST Imarat Finance Application?
# A: Rs 30,000/- or 0.2% of loan amount whichever is higher (Non-refundable)
# Q: Are there any late payment charges?
# A: Rs. 3,000/- per installment
# Q: What are the service/documentation/legal charges in NUST Imarat Finance?
# A: At actual
# Q: What are the valuation/BOQ charges?
# A: At actual
#
# Sheet: NUF
# Q: Is NUST Bank offering any financing product related to renewable/alternate energy solutions?
# A: NUST Bank has structured a new financing product under the name of “NUST Ujala Finance (NUST Ujala Finance)” in light of SBP’s refinance scheme, under the ambit of SME. The Product Program has been developed to provide financing for installation of solar energy equipment as an alternate source of energy.
# Q: who can apply for NUST Ujala Finance?
# A: 1. 	SE/ME Financing
# 2. 	Vendor’s / Suppliers’ Financing
# 3. 	NUST Employees’ Financing
# 4. 	Domestic Applicant Financing (exclusively for employees of corporate / government sector)
# Q: Is there any minimum age to avail financing in NUST Ujala Finance?
# A: SE/ME Financing:  Between 25-55 years at the time of application. (Any one partner/ director should meet age criteria)
# Vendors/Suppliers: Between 25-55 years at the time of application. (Any one partner/ director should meet age criteria)
# NUST Employees’ Financing: No age limit
# Domestic Applicant Financing: Between 25-55 years at the time of application. (Any one borrower or co-borrower should meet criteria)
# Q: For which purposes NUST Ujala Finance is being offered?
# A: SME, NUST Employees and Domestic: Energy generation for own use or for supply to the distribution company / NEPRA
# Q: Capacity allowed under NUST Ujala Finance?
# A: i. Business Enterprise : SE from 10 KW to 200KW, ME from 30 KW to 500KW
# ii. Domestic Borrowers from 5 KW to 30KW
# iii. NUST employees : upto 30 KW.
# Iv. Vendors/Suppliers: from 30 KW to 500KW
# Q: Loan Amount that can be availed under NUST Ujala Finance?
# A: i. Small Enterprise –  upto  Rs. 15 M
# ii. Medium Enterprise – upto Rs. 25M
# iii. Domestic users    - from Rs. 0.5M to Rs. 3.0M
# iv. NUST employees: - upto Rs. 3.00M
# v. Vendors/Suppliers:: From Rs. 5M to 25 Million – (Single Vendor)
# Q: What is the current Mark-up rate of NUST Ujala Finance?
# A: 6 % per annum for all
# *Markup at 12M Kibor + 4% Per Annum to be charged till refinance claim reimbursed by SBP.
# Q: What is the maximum tenure for NUST Ujala Finance?
# A: i. SE/ME borrowers:   05 years, inclusive of grace period of 03 months.
# ii. Domestic : 05 years inclusive of grace period of 03 months.
# iii. NUST employees : 10 years or as per remaining service period (whichever is lesser), inclusive of grace period of 03 months.
# iv. Vendors/Suppliers:  05 years inclusive of grace period of 06 months
# Q: What is the repayment frequency in NUST Ujala Finance?
# A: SE/ME Borrowers       :  Monthly  / Quarterly
# Domestic Borrower   :  Monthly
# NUST employees         : Monthly
# Vendors/Suppliers     : Quarterly/Half Yearly (as per borrower’s cash flow)
# Q: What are the processing charges for NUST Ujala Finance Application?
# A: SE/ME/Vendor/Supplier
# Q: Domestic Borrower
# A: NUST Employees
# Q: Is there any late payment charges?
# A: In case of delay of installment, commercial rate will be charges on overdue days.
# Q: What are the service/documentation/legal charges in NUST Ujala Finance?
# A: At actual
# Q: What are the insurance charges?
# A: At actual
#
# Sheet: NFMF
# Q: Is NUST Bank offering any seasonal financing?
# A: Seasonal finance product "NUST Flour Mill Finance” has been structured through for quick financing under program-based lending. The product has been designed for Flour Mills in order to meet their working capital needs. NUST Flour Mill Finance caters to meet seasonal financing needs of wheat procurement and other overhead expenses to flour mills. The scope of product is to target flour mills which fall under category of SME.
# Q: For which purposes NUST Flour Mill Finance is being offered?
# A: Cash Finance (CF)
# To meet working capital requirements of flour mill business for procurement of wheat as per milling capacity
# Q: What are the Loan Limits of NUST Flour Mill Finance?
# A: Per party (single entity) can avail up to Rs. 75M for ME and Rs. 25M for SE
# Q: Is there any minimum age to avail financing in NUST Flour Mill Finance?
# A: Age of borrower (in case of sole-proprietorship) must be minimum 20 years, however age not to exceed 65 years at the time of application. This age can be relaxed in case of effective succession planning for business operations.
# Q: What is the maximum tenure of NUST Flour Mill Finance?
# A: Maximum 1 year as per clean-up corridors
# Q: What is the current Mark-up rate of NUST Flour Mill Finance?
# A: Cash Finance
# 3 Months average KIBOR + 3% p.a.
# Q: Any Account turnover requirement for NUST Flour Mill Finance?
# A: Minimum 50% of applicant’s sales to be documented through account turnover with bank(s).
# Q: What are the processing charges for NUST Flour Mill Finance Application?
# A: Processing fee will be charged @ 0.15% of total limit(s) processed/approved or Rs. 25,000/- whichever is higher
# Q: What are the service/documentation/legal charges in NUST Flour Mill Finance?
# A: At actual
# Q: What are the insurance charges?
# A: At actual
#
# Sheet: NFBF
# Q: Is NUST Bank offering any financing against liquid security?
# A: NUST Fauri Business Finance” has been introduced to provide a swift package to meet financial business needs of new to bank obligor. AFBF is offered to meet short, medium and long-term requirements of business. The finance will be provided to SMEs & Commercial for all the eligible sectors as per NUST credit policy manual.
# Q: What is the Eligibility Criteria for business entity in Ask Fauri Business Finance?
# A: All except individuals
# Q: Is there any business age requirement?
# A: No
# Q: What is the nature of financing offered under Ask Fauri Business Finance?
# A: AFBF-1:   Running Finance
# AFBF-2:   Term Loan
# AFBF-3:   Letter of Guarantee
# AFBF-4:   Letter of Credit – Sight / Usance
# Q: What is the current Mark-up rate of Ask Fauri Business Finance?
# A: AFBF-1:  3MK /COD +1.50%
# AFBF-2:  12 MK /COD +2.0%
# AFBF-3:  As per SOC
# AFBF-4:  As per SOC
# Q: What is the principal repayment frequency in Ask Fauri Business Finance?
# A: AFBF-1:  At Maturity
# AFBF-2:  Monthly / Quarterly
# AFBF-3:  Upon expiry / redemption
# AFBF-4:  Upon retirement
# Q: What is the markup repayment frequency in Ask Fauri Business Finance?
# A: AFBF-1:  Monthly / Quarterly
# AFBF-2:  Monthly / Quarterly
# AFBF-3:  Upfront
# AFBF-4:  Upfront
# Q: What is the maximum tenure of Ask Fauri Business Finance?
# A: AFBF-1:   Up to 1 Year
# AFBF-2:   Up to 3 Year
# AFBF-3:   Up to 30 Months
# AFBF-4:   At Sight / Usance period 120 days
# Q: What are the Loan Limits of Ask Fauri Business Finance?
# A: Max Rs. 200 Mn (For all products)
# Q: Is there any grace period allowed in any financing?
# A: Grace period of 3 months allowed for AFBF 2 (Term Loan Only)
# Q: In how many days the loan can be approved in Ask Fauri Business Finance?
# A: Turnaround time (TAT) for disposal off the approval is fixed to 03 days from the date of pre-approval completion of documents
# Q: What is the collateral requirment for Ask Fauri Business Finance?
# A: •	NUST : Lien on NUST deposit CA/SA/ TDR, including 3rd party (LCY/FCY)
# •	National Saving Certificates (NSC): (Lien over NSC including joint name/owner)
# Q: What are the processing charges for Ask Fauri Finance Application?
# A: Flat @ Rs. 3,000/- (at the time of initiating and on each renewal)
# Q: What are the service/documentation/legal charges in Ask Fauri Business Finance?
# A: At actual
# Q: Is there any premature termination / Balloon payment charges?
# A: Nil
#
# Sheet: PMYB &ALS
# Q: Is NUST Bank Participating in PMYB & ALS?
# A: NUST Bank is actively participating in PMYB&ALS. It has been specially designed to provide self-employment opportunity to the unemployed youth of the country who have skills, knowledge, experience or willingness to start their own businesses on small to medium scale or expand existing business on vast scale.
# Q: For which purposes PMYB & ALS is being offered?
# A: •	To start new business
# •	To expand existing business
# Q: Nature of loans allowed in PMYB & ALS?
# A: •	Long term / Development Loans
# •	Working capital / Production Loans
# Q: What are the Loan Limits of PMYB & ALS?
# A: Tier 2
#  Above Rs. 0.5M and up to Rs 1.5M
# Q: Is there any minimum age to avail financing in PMYB & ALS and any mandatory qualification/experience required?
# A: All Pakistanis aged between 21 and 45 are eligible to apply, however for IT/E-Commerce related businesses, the lower age limit will be 18 years (at least matriculation or equivalent education will be required)
# Q: What is the maximum tenure in PMYB & ALS?
# A: Long Term Loan:  Maximum 8 Years (Maximum 1 Year Grace Period)
# Q: What is the current Mark-up rate of PMYB & ALS?
# A: Tier 2
#      5% per annum
# Q: Does the bank require any Equity for this scheme?
# A: Tier 2
# 10% (New Business)
# Q: What is the repayment frequency in PMYB & ALS?
# A: Repayment of PMYB&ALS loans will be made in the form of “monthly or quarterly Instalments (or as per SBP’s directives)
# Q: What is the security requirement for availing PMYB & ALS?
# A: Tier 2
# i.	Clean; personal guarantee of the borrower
# ii.	02 Post Dated cheques for installment amount
# iii.	01 Post Dated cheque for full loan amount plus mark up as per amortization schedule
# Q: Is there any quota for womens?
# A: 25% of the loans will go to women borrowers
# Q: What are the processing charges for PMYB & ALS?
# A: Rs. 100/-
# Q: What are the service/documentation/legal charges in PMYB & ALS?
# A: At actual
# Q: Is there any late payment charges?
# A: PKR 1,000/- plus FED per instance per installment, grace period included. (Late Payment to be triggered 15 days after installment becomes due i.e. on day 16)
#
# Sheet: NRF
# Q: Is NUST Bank offering any seasonal financing for rice mills?
# A: NUST Rice Finance caters to meet seasonal financing needs of paddy procurement and other overhead expenses to rice mills, based on past performance and milling capacity to fulfil their seasonal financial needs. The scope of the product is to target ‘Rice Mills’ which fall under the category of SME.
# Q: For which purposes NUST Rice Finance is being offered?
# A: Cash Finance (CF)
# To meet working capital requirements of Rice Husking Mills for procurement of paddy as per milling capacity.
# Q: What are the Loan Limits of NUST Rice Finance?
# A: ME: Upto Rs.200M (Maximum)
# SE:   Upto Rs.25M (Maximum)
# Q: Is there any minimum age to avail financing in NUST Rice Finance?
# A: Minimum 20 years (in case of sole proprietorship)
# Maximum 65 years at the time of application.
#
# * This criteria is not applicable if business concern is a partnership or limited company
# *This age can be relaxed in case of effective succession planning is available.
# Q: What is the maximum tenure of NUST Rice Finance?
# A: Cash Finance
# Max 270 Days or Clean-up corridors whichever is earlier
# Q: What is the current Mark-up rate of NUST Rice Finance?
# A: Cash Finance
# 3 Months KIBOR + Up to 3.00% p.a
# Q: Any Account turnover requirement for NUST Rice Finance?
# A: Minimum 50% of applicant’s sales to be documented through account turnover with bank(s).
# Q: What are the processing charges for NUST Rice Finance Application?
# A: Processing fee will be charged @ 0.15% of total limit(s) processed/approved or Rs. 25,000/- whichever is higher
# Q: What are the service/documentation/legal charges in NUST Rice Finance?
# A: At actual
# Q: What are the insurance charges?
# A: At actual
#
# Sheet: NHF
# Q: Is there any business loan product offered by NUST for families of armed forces and retired officers of the armed forces?
# A: NUST Hunarmand Finance is a sub product of PMYB&ALS which is structured with an objective to provide business opportunity to specific target market.
# •	Retired commissioned, junior commissioned, non-commissioned officers of the armed forces and their family members i.e. spouse and children
# •	Spouse and children of serving commissioned, junior commissioned and non-commissioned officers of armed forces.
# Q: For which purposes NUST Hunarmand Finance is being offered?
# A: •	To start new business
# •	To expand existing business
# Q: Nature of loan allowed in NUST Hunarmand Finance?
# A: •	Long term / Development Loans
# •	Working capital / Production Loans
# Q: What are the Loan Limits of NUST Hunarmand Finance?
# A: Tier 2
#  Above Rs. 0.5M and up to Rs 1.5M
# Q: Is there any minimum age to avail financing in NUST Hunarmand Finance?
# A: All Pakistanis aged between 21 and 45 are eligible to apply, however for IT/E-Commerce related businesses, the lower age limit will be 18 years
# Q: What is the maximum tenure in NUST Hunarmand Finance?
# A: Long Term Loan:  Maximum 8 Years (Maximum 1 Year Grace Period)
# Q: What is the current Mark-up rate of NUST Hunarmand Finance?
# A: Tier 2
# 4.5% per annum
# Q: Does the bank require any Equity for this scheme?
# A: Tier 2
# 10% (New Business)
# Q: What is the repayment frequency in NUST Hunarmand Finance?
# A: Repayment of AHF loans will be made in the form of “monthly or quarterly Instalments (or as per SBP’s directives)
# Q: What is the security requirement for availing NUST Hunarmand Finance?
# A: i.	Personal guarantee of borrower for loans up to 1.5M, and direct debit authority of borrower/pensioner/guarantor to be obtained
# ii.	For loans above 1.5M, it shall be secured against movable as well as immovable assets of borrowers as defined under PMYB&ALs
# iii.	Guarantee of serving officer of armed forces in case of his family (spouse or children) avail loan under this program.
# Q: Are there any late payment charges?
# A: Late payment charges PKR 1,000/- plus FED will be charges after 30th day of installment overdue.
# Q: What are the charges applicable for NUST Hunarmand Finance?
# A: Applicable as per PMYB & ALS
#
# Sheet: Nust Life
# Q: Can I purchase Bancassurnce policy from my account maintained with NUST Bank?
# A: Yes, every customer who attain the age of 18 and have account with NUST Bank can eligible to purchse Bancassurnce policy from his account.
# Q: What are the main features of NUST Life Bancassurnace Policy?
# A: -  Short term Family Protection and in Long term Savings
# Q: How many NUST Life  Insurance Plans available?
# A: o   NUST Life Value Plan
# Q: What are the main features of these NUST Life Insurance Plans
# A: - 14 Days Free Look Period start from the day customer received Policy Documents.
#
# Sheet: EFU Life
# Q: Can I purchase Bancassurnce policy from my account maintained with NUST Bank?
# A: Yes, every customer who attain the age of 18 and have account with NUST Bank can eligible to purchse Bancassurnce policy from his account.
# Q: What are the main features of EFU Bancassurnace Policy?
# A: -  Family Protection and Long term savings
# Q: How many EFU Insurance Plans available?
# A: o   EFU Savings and Protection Plan
# Q: What are the main features of these EFU Insurance Plans?
# A: - 14 Days Free Look Period start from the day customer received Policy Documents.
#
# Sheet: Jubilee Life
# Q: Can I purchase Bancassurnce policy from my account maintained with NUST Bank?
# A: Yes, every customer who attain the age of 18 and have account with NUST Bank can eligible to purchse Bancassurnce policy from his account.
# Q: What are the main features of JLI Bancassurnace Policy?
# A: -  Short term Family Protection and in Long term Savings
# Q: How many Jubilee Life Insurance Plans available?
# A: o   Jubilee Life Savings and Protection Plan
# Q: What are the main features of these Jubilee Life Insurance Plans
# A: - 14 Days Free Look Period start from the day customer received Policy Documents.
#
# Sheet: HOME REMITTANCE
# Q: What is Home Remittance ?
# A: Home Remittance Service enables remitters to send money from abroad to Pakistan instantly, conveniently, and safely through the legal banking channel.
# Q: What types of Inward Home Remittance products does NUST Bank offer ?
# A: NUST  offers the following Home Remittance Products to cater to the needs of various home remittance
# beneficiaries in Pakistan:
# • Cash Over the Counter (CoC) payments for walk-in customers
# • NUST Account Transfer
# • Other Bank Account Transfer via Inter Bank Funds Transfer (IBFT) & Real Time Gross Settlement (RTGS)
# Q: In which currency will I receive my remittance?
# A: All home remittance payments are disbursed in Pak Rupees.
# Q: Is there any limit on the amount received though NUST Home Remittance?
# A: Below are the applicable limits:
# • NUST Accounts - No Limit
# • Other banks accounts - No Limit
# • Cash Over the Counter (CoC) Transactions - Up to PKR 1,000,000/- per transaction and there is no limit of Western Union COC transactions
# Q: Are there any charges/fee for NUST's Home Remittance Service?
# A: NUST Home Remittance Service is free of charge.
# Q: Are there any tax deductions on Home Remittances?
# A: Home Remittance Service is free of taxes.
# Q: Can I receive remittance in Pakistan if I do not have a bank account with any bank?
# A: You can receive your home remittance from any of NUST 600+ domestic branches nationwide if you have a valid CNIC and Transaction Unique Reference No. / Pin code.
# Q: Is there any list of branches I can access to get information?
# A: The list of NUST domestic branches can be viewed from the Branch Locator available on our corporate website www.nustbank.com .
# Q: Who should I contact in case I need to lodge a complaint regarding Home Remittance?
# A: For any query/complaint regarding Home Remittance, you may contact our dedicated Remittance Service Centre at UAN# 021-111-000-787.
# You may also email your queries/complaints at remittance@NUSTbank.com.pk
# Q: How can I obtain a Proceed Realization Certificate (PRC)/Encashment Certificate against remittance(s) received? Who should I contact?
# A: Please find below contact details for obtaining a PRC and e-PRC:
#  •  e-PRC option is also available at the NUST website https://secureportal.NUSTbank.com/eprc/customer to obtain a system generated PRC on your registered email address.
#  • Proceeds Realization Certificate (PRC) is issued from NUST Centralized Remittance Department. You may contact them at the following email addresses:
# remittance.prc@NUSTbank.com.pk
# Q: Can I track my remittance status online?
# A: Yes, you can view the status of your remittance online through NUST Remittance Tracker by following link https://NUSTbank.com/services/alternate-delivery-channels/home-remittance-tracking/
# Q: What are NUST's Banking hours to avail home remittance services from NUST Branches?
# A: Customers can avail home remittance services from NUST domestic branches during regular business hours appended below:
# • Monday to Thursday: 09:00 am to 05:00 pm
# • Friday: 09:00 am to 05:30 pm
# • Saturday: 09:00 am to 01:30 pm (through selected branches)
# Q: Is it important to declare the purpose of the funds being sent to Pakistan?
# A: Yes, it is mandatory to provide purpose of funds being sent to Pakistan.
# Q: I am a foreign national, can I send money to Pakistan?
# A: Yes, you can.
# Q: Does the PRI comes under the laws of State Bank or Government?
# A: It is a joint initiative of  State Bank of Pakistan, Ministry of overseas Pakistanis and Ministry of Finance.
# Q: Can the Freelance payment  be made through PRI?
# A: Yes Freelance payments is allowed under specfic arrangemnts with Tie-ups with allowed purposes as per SBP guidelines.
# Q: What conversion rates will be applied on remittance?
# A: The same conversion rates will be applied at the time of sending the remittance. Affiliated bank or Exchange Company confirm the Conversion rates to Sender at the time of sending the remittance.
# Q: Does NUST Bank has specialized remittance Account as per SBP guideline?
# A: Yes NUST has remittance account name as Pak Wattan Remittance Account.
# Q: Who can open Pak Wattan Remittance Account?
# A: A Bonafide recipient of Home remittance (PRI) can open this account.
# Q: Can remittance be sent from anywhere to Pakistan?
# A: Yes, remittance can be sent from around the globe to Pakistan through our agent Partners like Western Union, Mastercard, Dandelion Payments (RIA) etc.
# For more information please go through the below link:

# %% [markdown]
# Converting QA dataset to `Prompt Completion` Format

# %%
prompt_completion_dataset = []

for sheet_name, qa_list in qa_dict.items():
    for question, answer in qa_list:
        prompt_completion = {
            "prompt": [{"role": "user", "content": question}],
            "completion": [{"role": "assistant", "content": answer}]
        }
        prompt_completion_dataset.append(prompt_completion)

print(f"Generated {len(prompt_completion_dataset)} prompt-completion pairs from {len(qa_dict)} sheets.")
# Out:
# Generated 304 prompt-completion pairs from 35 sheets.

# %%
for item in prompt_completion_dataset[:3]:
    print(item)
# Out:
# {'prompt': [{'role': 'user', 'content': 'I would like to open an account with my son, do u have any product for kids?'}], 'completion': [{'role': 'assistant', 'content': 'Yes our product is Little Champs Account. It is designed specifically for minors (individuals below the age of 18 years). A child requires the help of a parental/legal guardian to open this account and avail its facilities. Little Champs get a Debit Card and chequebook which is free the first time'}]}
# {'prompt': [{'role': 'user', 'content': 'What are the main Features  of the Little Champs Account.'}], 'completion': [{'role': 'assistant', 'content': 'Minimum initial deposit of Rs.100/-'}]}
# {'prompt': [{'role': 'user', 'content': 'What other Value added features does the Little Champs Account have?'}], 'completion': [{'role': 'assistant', 'content': 'Attractive returns on savings account'}]}

# %%
import json
output_filename = "BankProducts_FineTuning.json"
with open(output_filename, "w", encoding="utf-8") as f:
    json.dump(prompt_completion_dataset, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Loading *Funds Transfer* dataset

# %%
with open("/home/muhammadbinusman/Downloads/funds_transfer_app_features_faq (1).json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
# Prepare output list
prompt_completion_dataset = []

for category_obj in data.get("categories", []):
    category_name = category_obj.get("category", "")
    questions = category_obj.get("questions", [])
    
    for qa in questions:
        question_text = qa.get("question", "").strip()
        answer_text = qa.get("answer", "").strip()
        
        prompt_completion = {
            "prompt": [{"role": "user", "content": question_text}],
            "completion": [{"role": "assistant", "content": answer_text}]
        }
        
        prompt_completion_dataset.append(prompt_completion)
print(f"Generated {len(prompt_completion_dataset)} prompt-completion pairs.")
# Out:
# Generated 15 prompt-completion pairs.

# %%
git config user.name "MuhammadBinUsman03"

# %%
# Save to JSON
output_filename = "finetune_data.json"

with open(output_filename, "w", encoding="utf-8") as f:
    json.dump(prompt_completion_dataset, f, ensure_ascii=False, indent=2)

print(f"Saved to '{output_filename}'")
# Out:
# Saved to 'finetune_data.json'
